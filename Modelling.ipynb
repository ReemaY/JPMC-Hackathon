# %%
import pandas as pd
import numpy as np
from google.colab import drive

drive.mount('/content/gdrive')
root_path = "gdrive/My Drive/JPMC_Hackathon/"
data_path = root_path + "data/"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
raw_data = pd.read_csv(data_path+"Goal4.csv")

df = pd.read_csv(data_path+"Goal4.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,9,16,17,19,21,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Goal Target Indicator  ... Unnamed: 49 Unnamed: 50  Unnamed: 51
# 0          4    4.1     4.1.1  ...         NaN         NaN          NaN
# 1          4    4.1     4.1.1  ...         NaN         NaN          NaN
# 2          4    4.1     4.1.1  ...         NaN         NaN          NaN
# 3          4    4.1     4.1.1  ...         NaN         NaN          NaN
# 4          4    4.1     4.1.1  ...         NaN         NaN          NaN
# ...      ...    ...       ...  ...         ...         ...          ...
# 191757     4    4.c     4.c.1  ...         NaN         NaN          NaN
# 191758     4    4.c     4.c.1  ...         NaN         NaN          NaN
# 191759     4    4.c     4.c.1  ...         NaN         NaN          NaN
# 191760     4    4.c     4.c.1  ...         NaN         NaN          NaN
# 191761     4    4.c     4.c.1  ...         NaN         NaN          NaN
#
# [191762 rows x 52 columns]

# %%
df['Target'].unique()
# Out:
# array([4.1, 4.2, 4.3, 4.4, 4.5, '4.5', '4.6', '4.a', '4.b', '4.c'],
#       dtype=object)

# %%
len(df['SeriesDescription'].unique())
# Out:
# 29

# %%
df['SeriesDescription'].unique()
# Out:
# array(['Proportion of children and young people achieving a minimum proficiency level in reading and mathematics (%)',
#        'Completion rate, by sex, location, wealth quintile and education level (%)',
#        'Proportion of children aged 36−59 months who are developmentally on track in at least three of the following domains: literacy-numeracy, physical development, social-emotional development, and learning (% of children aged 36-59 months)',
#        'Participation rate in organized learning (one year before the official primary entry age), by sex (%)',
#        'Participation rate in formal and non-formal education and training, by sex (%)',
#        'Proportion of youth and adults with information and communications technology (ICT) skills, by sex and type of skill (%)',
#        'Adjusted gender parity index for completion rate, by sex, location, wealth quintile and education level',
#        'Adjusted location parity index for completion rate, by sex, location, wealth quintile and education level',
#        'Adjusted wealth parity index for completion rate, by sex, location, wealth quintile and education level',
#        'Gender parity index for youth/adults with information and communications technology (ICT) skills, by type of skill (ratio)',
#        'Gender parity index for participation rate in formal and non-formal education and training (ratio)',
#        'Gender parity index for participation rate in organized learning (one year before the official primary entry age), (ratio)',
#        'Gender parity index of trained teachers, by education level (ratio)',
#        'Immigration status parity index for achieving at least a fixed level of proficiency in functional skills, by numeracy/literacy skills (ratio)',
#        'Language test parity index for achievement (ratio)',
#        'Native parity index for achievement (ratio)',
#        'Gender parity index for achievement (ratio)',
#        'Rural to urban parity index for achievement (ratio)',
#        'Low to high socio-economic parity status index for achievement (ratio)',
#        'Proportion of population achieving at least a fixed level of proficiency in functional skills, by sex, age and type of skill (%)',
#        'Schools with basic handwashing facilities, by education level (%)',
#        'Schools with access to\xa0computers for pedagogical purposes, by education level (%)',
#        'Schools with access to\xa0electricity, by education level (%)',
#        'Schools with access to basic drinking water, by education level (%)',
#        'Schools with access to the internet for pedagogical purposes, by education level (%)',
#        'Schools with access to\xa0access to single-sex basic sanitation, by education level (%)',
#        'Proportion of schools with access to adapted infrastructure and materials for students with disabilities, by education level (%)',
#        'Total official flows for scholarships, by recipient countries (millions of constant 2018 United States dollars)',
#        'Proportion of teachers who have received at least the minimum organized teacher training (e.g. pedagogical training) pre-service or in-service required for teaching at the relevant level in a given country, by sex and education level (%)'],
#       dtype=object)

# %%
len(df['Indicator'].unique())
# Out:
# 11

# %%
df['Indicator'].unique()
# Out:
# array(['4.1.1', '4.1.2', '4.2.1', '4.2.2', '4.3.1', '4.4.1', '4.5.1',
#        '4.6.1', '4.a.1', '4.b.1', '4.c.1'], dtype=object)

# %%
len(df['SeriesCode'].unique())
# Out:
# 29

# %%
df.describe()
# Out:
#            Goal    GeoAreaCode  ...  Unnamed: 50  Unnamed: 51
# count  191762.0  191762.000000  ...          0.0          0.0
# mean        4.0     396.544002  ...          NaN          NaN
# std         0.0     250.320400  ...          NaN          NaN
# min         4.0       1.000000  ...          NaN          NaN
# 25%         4.0     188.000000  ...          NaN          NaN
# 50%         4.0     372.000000  ...          NaN          NaN
# 75%         4.0     600.000000  ...          NaN          NaN
# max         4.0     921.000000  ...          NaN          NaN
#
# [8 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'TimePeriod', 'Value', 'Time_Detail',
#        'TimeCoverage', 'UpperBound', 'LowerBound', 'BasePeriod', 'Source',
#        'GeoInfoUrl', 'FootNote', 'Age', 'Education level', 'Location',
#        'Nature', 'Quantile', 'Reporting Type', 'Sex', 'Type of skill', 'Units',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
#        'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50', 'Unnamed: 51'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
       'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
       'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
       'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
       'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
       'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
       'Unnamed: 50', 'Unnamed: 51'],axis=1)

# %%
df = df.drop(['Goal','Target','Indicator','TimePeriod'],axis=1)

# %%
df.describe()
# Out:
#          GeoAreaCode          Value  ...  BasePeriod  GeoInfoUrl
# count  191762.000000  179570.000000  ...      2276.0         0.0
# mean      396.544002      41.595042  ...      2018.0         NaN
# std       250.320400      41.230603  ...         0.0         NaN
# min         1.000000       0.000000  ...      2018.0         NaN
# 25%       188.000000       1.001600  ...      2018.0         NaN
# 50%       372.000000      34.134145  ...      2018.0         NaN
# 75%       600.000000      83.482728  ...      2018.0         NaN
# max       921.000000    1632.065770  ...      2018.0         NaN
#
# [8 rows x 7 columns]

# %%
len(df)
# Out:
# 191762

# %%
df.isna().sum()
# Out:
# SeriesCode                0
# SeriesDescription         0
# GeoAreaCode               0
# GeoAreaName               0
# Value                 12192
# Time_Detail               0
# TimeCoverage         191762
# UpperBound           191762
# LowerBound           191762
# BasePeriod           189486
# Source                    0
# GeoInfoUrl           191762
# FootNote             176950
# Age                  191281
# Education level       17879
# Location              78911
# Nature                    0
# Quantile              55387
# Reporting Type            0
# Sex                   48829
# Type of skill        175898
# Units                     0
# dtype: int64

# %%
df = df.drop(['TimeCoverage','UpperBound','LowerBound','GeoInfoUrl'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-239-df8d008ad2a1> in <module>()
# ----> 1 df = df.drop(['TimeCoverage','UpperBound','LowerBound','GeoInfoUrl'],axis=1)
#       2
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3921                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3922             else:
# -> 3923                 new_axis = axis.drop(labels, errors=errors)
#    3924             result = self.reindex(**{axis_name: new_axis})
#    3925
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5285         if mask.any():
#    5286             if errors != "ignore":
# -> 5287                 raise KeyError(f"{labels[mask]} not found in axis")
#    5288             indexer = indexer[~mask]
#    5289         return self.delete(indexer)
#
# KeyError: "['TimeCoverage' 'UpperBound' 'LowerBound' 'GeoInfoUrl'] not found in axis"

# %%
df = df.drop(['GeoAreaCode','BasePeriod','Age','FootNote','Source','Reporting Type','Units'],axis=1)

# %%
df = df.drop(['Nature'],axis=1)

# %%
df = df.drop(['Quantile'],axis=1)

# %%
df = df.drop(['Location'],axis=1)

# %%
df_afghanistan = df[(df.GeoAreaName == 'Afghanistan')]
df_afghanistan
# Out:
#             SeriesCode  ... Type of skill
# 0          SE_TOT_PRFL  ...    SKILL_MATH
# 1          SE_TOT_PRFL  ...    SKILL_READ
# 2          SE_TOT_PRFL  ...    SKILL_READ
# 3          SE_TOT_PRFL  ...    SKILL_READ
# 4          SE_TOT_PRFL  ...    SKILL_READ
# ...                ...  ...           ...
# 175972  DC_TOF_SCHIPSL  ...           NaN
# 175973  DC_TOF_SCHIPSL  ...           NaN
# 175974  DC_TOF_SCHIPSL  ...           NaN
# 175975  DC_TOF_SCHIPSL  ...           NaN
# 175976  DC_TOF_SCHIPSL  ...           NaN
#
# [649 rows x 11 columns]

# %%
df_afghanistan['Time_Detail'].unique()
# Out:
# array([2013, 2016, 2011, 2015, '2011', '2015', 2017, 2018, 2006, 2007,
#        2008, 2009, 2010, 2012, 2014], dtype=object)

# %%
len(df_afghanistan)
# Out:
# 649

# %%
df_afghanistan
# Out:
#             SeriesCode  ... Type of skill
# 0          SE_TOT_PRFL  ...    SKILL_MATH
# 1          SE_TOT_PRFL  ...    SKILL_READ
# 2          SE_TOT_PRFL  ...    SKILL_READ
# 3          SE_TOT_PRFL  ...    SKILL_READ
# 4          SE_TOT_PRFL  ...    SKILL_READ
# ...                ...  ...           ...
# 175972  DC_TOF_SCHIPSL  ...           NaN
# 175973  DC_TOF_SCHIPSL  ...           NaN
# 175974  DC_TOF_SCHIPSL  ...           NaN
# 175975  DC_TOF_SCHIPSL  ...           NaN
# 175976  DC_TOF_SCHIPSL  ...           NaN
#
# [649 rows x 11 columns]

# %%
df_afghanistan['SeriesCode'].unique()
# Out:
# array(['SE_TOT_PRFL', 'SE_TOT_CPLR', 'SE_AGP_CPRA', 'SE_ALP_CPLR',
#        'SE_AWP_CPRA', 'SE_TOT_GPI', 'SE_TOT_RUPI', 'SE_ACC_HNDWSH',
#        'SE_ACS_ELECT', 'SE_ACS_H2O', 'SE_ACS_SANIT', 'DC_TOF_SCHIPSL'],
#       dtype=object)

# %%
df['GeoAreaName'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Azerbaijan', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Armenia',
#        'Belgium', 'Bhutan', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'Belize', 'Brunei Darussalam', 'Bulgaria', 'Burundi',
#        'Belarus', 'Cambodia', 'Cameroon', 'Canada', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo',
#        'Democratic Republic of the Congo', 'Costa Rica', 'Croatia',
#        'Cuba', 'Cyprus', 'Czechia', 'Benin', 'Denmark',
#        'Dominican Republic', 'Ecuador', 'El Salvador', 'Estonia',
#        'Finland', 'France', 'Gabon', 'Georgia', 'Gambia',
#        'State of Palestine', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Honduras', 'China, Hong Kong Special Administrative Region',
#        'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran (Islamic Republic of)', 'Ireland', 'Israel', 'Italy',
#        "Côte d'Ivoire", 'Japan', 'Kazakhstan', 'Jordan', 'Kenya',
#        "Democratic People's Republic of Korea", 'Republic of Korea',
#        'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic",
#        'Lebanon', 'Lesotho', 'Latvia', 'Liechtenstein', 'Lithuania',
#        'Luxembourg', 'China, Macao Special Administrative Region',
#        'Madagascar', 'Malawi', 'Malaysia', 'Malta', 'Mauritania',
#        'Mauritius', 'Mexico', 'Mongolia', 'Republic of Moldova',
#        'Montenegro', 'Morocco', 'Mozambique', 'Oman', 'Namibia',
#        'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Norway',
#        'Pakistan', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Qatar', 'Romania', 'Russian Federation',
#        'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'Slovakia', 'Viet Nam', 'Slovenia', 'South Africa',
#        'Zimbabwe', 'Spain', 'Suriname', 'Eswatini', 'Sweden',
#        'Switzerland', 'Syrian Arab Republic', 'Thailand', 'Togo',
#        'Trinidad and Tobago', 'United Arab Emirates', 'Tunisia', 'Turkey',
#        'Uganda', 'Ukraine', 'North Macedonia', 'Egypt',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United Republic of Tanzania', 'United States of America',
#        'Burkina Faso', 'Uruguay', 'Yemen', 'Zambia', 'Angola', 'Barbados',
#        'Bolivia (Plurinational State of)', 'Myanmar',
#        'Central African Republic', 'Sri Lanka', 'Equatorial Guinea',
#        'Ethiopia', 'Fiji', 'Djibouti', 'Guinea', 'Guyana', 'Haiti',
#        'Iraq', 'Jamaica', 'Liberia', 'Maldives', 'Mali', 'Nepal',
#        'Vanuatu', 'Nigeria', 'Guinea-Bissau', 'Timor-Leste',
#        'Puerto Rico', 'Rwanda', 'Saint Lucia', 'Sao Tome and Principe',
#        'Somalia', 'South Sudan', 'Sudan', 'Tajikistan', 'Turkmenistan',
#        'Uzbekistan', 'Venezuela (Bolivarian Republic of)', 'World',
#        'South-Eastern Asia', 'Western Asia', 'Sub-Saharan Africa',
#        'Kiribati', 'Marshall Islands',
#        'Small island developing States (SIDS)', 'Tonga', 'Samoa',
#        'Oceania', 'Northern Africa', 'Northern America',
#        'Antigua and Barbuda', 'Southern Asia', 'Bahamas',
#        'Australia and New Zealand', 'Bermuda',
#        'Central and Southern Asia', 'Solomon Islands',
#        'British Virgin Islands', 'Cabo Verde', 'Central Asia', 'Europe',
#        'Cook Islands', 'Least Developed Countries (LDCs)', 'Dominica',
#        'Eritrea', 'Gibraltar', 'Grenada', 'Holy See',
#        'Latin America and the Caribbean',
#        'Landlocked developing countries (LLDCs)', 'Montserrat',
#        'Europe and Northern America', 'Nauru', 'Aruba',
#        'Sint Maarten (Dutch part)',
#        'Oceania (exc. Australia and New Zealand)', 'Niue',
#        'Micronesia (Federated States of)', 'Palau', 'Papua New Guinea',
#        'Saint Kitts and Nevis', 'Anguilla',
#        'Saint Vincent and the Grenadines', 'San Marino',
#        'Northern Africa and Western Asia',
#        'Eastern and South-Eastern Asia', 'Tokelau', 'Tuvalu', 'Andorra',
#        'Kosovo', 'Curaçao', 'Cayman Islands', 'Monaco',
#        'Turks and Caicos Islands', 'Eastern Asia', 'Africa',
#        'South America', 'Western Africa', 'Central America',
#        'Eastern Africa', 'Middle Africa', 'Southern Africa', 'Caribbean',
#        'Southern Europe', 'Melanesia', 'Micronesia', 'Polynesia',
#        'Southern Asia (excluding India)', 'Caucasus and Central Asia',
#        'Asia', 'Eastern Europe',
#        'Eastern Asia (excluding Japan and China)', 'Libya',
#        'Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand)',
#        'Developing regions', 'Wallis and Futuna Islands', 'ODA residual'],
#       dtype=object)

# %%
df_afghanistan[df_afghanistan['SeriesCode'] == 'SE_TOT_PRFL']
# Out:
#     SeriesCode  ... Type of skill
# 0  SE_TOT_PRFL  ...    SKILL_MATH
# 1  SE_TOT_PRFL  ...    SKILL_READ
# 2  SE_TOT_PRFL  ...    SKILL_READ
# 3  SE_TOT_PRFL  ...    SKILL_READ
# 4  SE_TOT_PRFL  ...    SKILL_READ
# 5  SE_TOT_PRFL  ...    SKILL_MATH
# 6  SE_TOT_PRFL  ...    SKILL_MATH
# 7  SE_TOT_PRFL  ...    SKILL_MATH
#
# [8 rows x 11 columns]

# %%
df_afghanistan.columns
# Out:
# Index(['SeriesCode', 'SeriesDescription', 'GeoAreaName', 'Value',
#        'Time_Detail', 'Education level', 'Location', 'Nature', 'Quantile',
#        'Sex', 'Type of skill'],
#       dtype='object')

# %%
feat_mat = df.groupby(['Sex','Type of skill','Education level']).size().reset_index(name='Freq')
feat_mat
# Out:
#         Sex Type of skill Education level  Freq
# 0   BOTHSEX    SKILL_MATH          GRAD23   153
# 1   BOTHSEX    SKILL_MATH          LOWSEC   437
# 2   BOTHSEX    SKILL_MATH          PRIMAR   115
# 3   BOTHSEX    SKILL_READ          GRAD23   174
# 4   BOTHSEX    SKILL_READ          LOWSEC   413
# 5   BOTHSEX    SKILL_READ          PRIMAR   105
# 6    FEMALE    SKILL_MATH          GRAD23   150
# 7    FEMALE    SKILL_MATH          LOWSEC   405
# 8    FEMALE    SKILL_MATH          PRIMAR   104
# 9    FEMALE    SKILL_READ          GRAD23   166
# 10   FEMALE    SKILL_READ          LOWSEC   381
# 11   FEMALE    SKILL_READ          PRIMAR    90
# 12     MALE    SKILL_MATH          GRAD23   150
# 13     MALE    SKILL_MATH          LOWSEC   405
# 14     MALE    SKILL_MATH          PRIMAR   104
# 15     MALE    SKILL_READ          GRAD23   166
# 16     MALE    SKILL_READ          LOWSEC   381
# 17     MALE    SKILL_READ          PRIMAR    90

# %%
feat_mat.shape
# Out:
# (18, 4)

# %%
feat_name_list = []

for s in feat_mat['Sex']:
  for t in feat_mat['Type of skill']:
    for e in feat_mat['Education level']:
      feat_name = s+"."+t+"."+e
      feat_name_list.append(feat_name)
feat_name_list = list(set(feat_name_list))

# %%
feat_name_list
# Out:
# ['BOTHSEX.SKILL_READ.GRAD23',
#  'BOTHSEX.SKILL_READ.LOWSEC',
#  'FEMALE.SKILL_MATH.GRAD23',
#  'FEMALE.SKILL_MATH.LOWSEC',
#  'MALE.SKILL_MATH.GRAD23',
#  'BOTHSEX.SKILL_MATH.PRIMAR',
#  'MALE.SKILL_READ.GRAD23',
#  'MALE.SKILL_MATH.LOWSEC',
#  'FEMALE.SKILL_READ.LOWSEC',
#  'BOTHSEX.SKILL_READ.PRIMAR',
#  'FEMALE.SKILL_READ.GRAD23',
#  'BOTHSEX.SKILL_MATH.LOWSEC',
#  'MALE.SKILL_READ.PRIMAR',
#  'FEMALE.SKILL_READ.PRIMAR',
#  'BOTHSEX.SKILL_MATH.GRAD23',
#  'MALE.SKILL_MATH.PRIMAR',
#  'MALE.SKILL_READ.LOWSEC',
#  'FEMALE.SKILL_MATH.PRIMAR']

# %%
len(feat_name_list)
# Out:
# 18

# %%
listOfDataFrames = []
num_feat = 0
for feat in feat_name_list:
  num_feat += 1
  df_thisFeat = pd.DataFrame(columns=['GeoAreaName','Time_Detail',feat])
  featSplit = feat.split(".")
  print(featSplit)
  sex = featSplit[0]
  typeOfSkill = featSplit[1]
  educationLevel = featSplit[2]

  num_country = 0
  for country in df['GeoAreaName'].unique():
    num_country += 1
    df_country = df[(df.GeoAreaName == country)]

    yearsForThisCountry = df_country['Time_Detail'].unique()
    print(country,yearsForThisCountry)
    for year in yearsForThisCountry:
      print(feat,country,year)

      df_countryYear = df_country[df_country['Time_Detail']==year]
     
      df_subset = df_countryYear[(df_countryYear['Sex']==sex) & \
                             (df_countryYear['Type of skill']==typeOfSkill) & \
                             (df_countryYear['Education level']==educationLevel)]
      



      val = df_subset["Value"].values
      print(val)
      if len(val) == 1:
        print(df_subset)
        print(df_subset["Value"])
        d = {'GeoAreaName':country,'Time_Detail':year,feat:val[0]}
        print(d)
        print("******")
        df_thisFeat = df_thisFeat.append(d,ignore_index=True)
        print(df_thisFeat.shape)

    #if num_country == 10:
    #  break

  listOfDataFrames.append(df_thisFeat)
  #if num_feat == 3:
  #    break
# Out:
# Streaming output truncated to the last 5000 lines.
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Burkina Faso 2012
# []
# Uruguay [2003 2006 2009 2012 2013 2015 2018 '2000' '2001' '2002' '2003' '2004'
#  '2005' '2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015' '2016'
#  '2017' '2018' '2006' '2007' 2000 2001 2002 2004 2005 2008 2010 2011 2014
#  2016 2017 2007]
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2006
# [73.38843629]
#        SeriesCode  ... Type of skill
# 3926  SE_TOT_PRFL  ...    SKILL_MATH
#
# [1 rows x 8 columns]
# 3926    73.388436
# Name: Value, dtype: float64
# {'GeoAreaName': 'Uruguay', 'Time_Detail': 2006, 'FEMALE.SKILL_MATH.PRIMAR': 73.3884362888555}
# ******
# (102, 3)
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2013
# [67.05489614]
#        SeriesCode  ... Type of skill
# 3954  SE_TOT_PRFL  ...    SKILL_MATH
#
# [1 rows x 8 columns]
# 3954    67.054896
# Name: Value, dtype: float64
# {'GeoAreaName': 'Uruguay', 'Time_Detail': 2013, 'FEMALE.SKILL_MATH.PRIMAR': 67.05489614243321}
# ******
# (103, 3)
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Uruguay 2007
# []
# Yemen [2003 2007 2011 '2006' '2013' '2010' '2014' 2006 2013 2014 2010 2016 2008
#  2009 2012 2015 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Yemen 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Yemen 2018
# []
# Zambia [2006 2015 '2001' '2007' '2010' '2013' '2017' 2001 2007 2010 2013 2017
#  2012 2016 2008 2009 2011 2014 2018]
# FEMALE.SKILL_MATH.PRIMAR Zambia 2006
# [0.9]
#        SeriesCode  ... Type of skill
# 3980  SE_TOT_PRFL  ...    SKILL_MATH
#
# [1 rows x 8 columns]
# 3980    0.9
# Name: Value, dtype: float64
# {'GeoAreaName': 'Zambia', 'Time_Detail': 2006, 'FEMALE.SKILL_MATH.PRIMAR': 0.9}
# ******
# (104, 3)
# FEMALE.SKILL_MATH.PRIMAR Zambia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Zambia 2018
# []
# Angola [2015 '2016' '2004' '2011' '2015' 2004 2011 2016 2010 2006 2007 2008 2009
#  2012 2013 2014 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Angola 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Angola 2018
# []
# Barbados [2012 '2012' '2000' '2001' '2002' '2003' '2004' '2005' '2006' '2007'
#  '2008' '2009' '2010' '2011' 2000 2001 2002 2003 2004 2005 2006 2007 2008
#  2009 2010 2011 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Barbados 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Barbados 2018
# []
# Bolivia (Plurinational State of) [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2011 2012 2013 2014
#  2015 2016 2017 2018 '2000' '2001' '2002' '2003' '2004' '2005' '2006'
#  '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015' '2016'
#  '2017' '2018' 2010]
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Bolivia (Plurinational State of) 2010
# []
# Myanmar [2000 2016 '2015' '2017' '2000' '2016' 2015 2017 2001 2002 2003 2004 2005
#  2006 2007 2008 2009 2010 2014 2018 2012 2011 2013]
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Myanmar 2013
# []
# Central African Republic [2000 2006 2010 '2018-2019' '2008' '2009' '2011' '2000' '2006' '2010' 2008
#  2009 2011 2016 2007 2012 2013 2014 2015 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2018-2019
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Central African Republic 2018
# []
# Sri Lanka [2006 '2010' '2011' '2013' '2014' '2015' '2016' '2006' 2010 2013 2014 2015
#  2016 2017 2018 2012 2007 2008 2009 2011]
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Sri Lanka 2011
# []
# Equatorial Guinea [2000 '2000' '2003' '2011' '2015' 2011 2015 2005 2008 2009 2010 2006 2007
#  2012 2013 2014 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Equatorial Guinea 2018
# []
# Ethiopia [2000 2005 2007 2011 2016 '2007' '2008' '2009' '2010' '2011' '2012' '2014'
#  '2015' '2013' 2013 2008 2009 2010 2012 2014 2015 2001 2002 2003 2004 2006
#  2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Ethiopia 2018
# []
# Fiji [2007 '2004' '2006' '2011' '2016' 2004 2006 2008 2011 2012 2016 2009 2010
#  2013 2014 2015 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Fiji 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Fiji 2018
# []
# Djibouti [2006 '2000' '2001' '2002' '2004' '2006' '2007' '2008' '2009' '2011'
#  '2016' '2017' '2018' '2019' 2000 2001 2002 2004 2007 2008 2009 2011 2016
#  2017 2018 2019 2013 2014 2015 2010 2012]
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2019
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2019
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Djibouti 2012
# []
# Guinea [2005 2012 2016 '2016' '2004' '2005' '2006' '2007' '2008' '2009' '2010'
#  '2011' '2013' '2014' 2004 2006 2007 2008 2009 2010 2011 2013 2014 2015
#  2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Guinea 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea 2018
# []
# Guyana [2000 2006 2009 2014 '2014' '2003' '2008' '2009' '2010' '2011' '2012'
#  '2017' 2017 2003 2008 2010 2011 2012 2001 2005 2007 2013 2015 2016 2018]
# FEMALE.SKILL_MATH.PRIMAR Guyana 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Guyana 2018
# []
# Haiti [2000 2003 2005 2012 2017 '2016-2017' 2006 2007 2008 2009 2010 2011 2013
#  2014 2015 2016 2018]
# FEMALE.SKILL_MATH.PRIMAR Haiti 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2016-2017
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Haiti 2018
# []
# Iraq [2000 2006 2011 '2018' '2000' '2003' '2004' '2007' '2012' '2014' '2017'
#  2007 2012 2003 2004 2008 2009 2010 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Iraq 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Iraq 2018
# []
# Jamaica [2001 2005 2011 '2011' '2013' '2014' '2015' '2016' '2017' '2018' 2015 2013
#  2014 2016 2017 2018 2010 2008 2009 2012]
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Jamaica 2012
# []
# Liberia [2007 2008 2013 '2000' '2014' '2015' '2017' 2000 2014 2015 2017 2006 2009
#  2011 2016 2010 2012 2018]
# FEMALE.SKILL_MATH.PRIMAR Liberia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Liberia 2018
# []
# Maldives [2008 2017 '2016-2017' '2000' '2001' '2002' '2005' '2006' '2007' '2015'
#  '2016' '2017' 2016 2000 2001 2002 2005 2006 2007 2015 2003 2009 2010 2011
#  2012 2013 2014 2018]
# FEMALE.SKILL_MATH.PRIMAR Maldives 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2016-2017
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Maldives 2018
# []
# Mali [2001 2006 2009 2010 2013 2015 '2015' '2009' '2010' '2011' '2013' '2014'
#  '2016' '2017' '2018' 2014 2016 2011 2017 2018 2005 2008 2007 2012]
# FEMALE.SKILL_MATH.PRIMAR Mali 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Mali 2012
# []
# Nepal [2001 2007 2011 2014 2016 '2019' '2011' '2013' '2014' '2015' '2016' '2017'
#  '2008' 2008 2015 2017 2019 2000 2002 2003 2004 2005 2010 2012 2013 2006
#  2009 2018]
# FEMALE.SKILL_MATH.PRIMAR Nepal 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2019
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2019
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Nepal 2018
# []
# Vanuatu [2007 '2009' 2009 2015 2006 2008 2010 2011 2012 2013 2014 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Vanuatu 2018
# []
# Nigeria [2003 2007 2008 2010 2011 2013 2016 '2016-2017' 2004 2005 2006 2009 2012
#  2014 2015 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2016-2017
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Nigeria 2018
# []
# Guinea-Bissau [2000 2006 2014 '2018-2019' '2000' '2018-19' 2010 2007 2008 2009 2011 2012
#  2013 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2018-2019
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2018-19
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Guinea-Bissau 2018
# []
# Timor-Leste [2009 2016 '2016' '2013' '2014' '2015' '2017' '2018' '2010' 2010 2013 2014
#  2015 2017 2018 2006 2007 2008 2011 2012]
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Timor-Leste 2012
# []
# Puerto Rico ['2010' '2011' '2012' '2013' 2010 2011 2012 2013 2014 2015 2016]
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Puerto Rico 2016
# []
# Rwanda ['2000' '2002' '2005' '2010' '2015' '2014-2015' '2016' '2017' '2018' 2000
#  2002 2005 2010 2015 2017 2016 2018 2001 2003 2004 2006 2007 2008 2009
#  2011 2012 2013 2014]
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2014-2015
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Rwanda 2014
# []
# Saint Lucia ['2012' '2000' '2001' '2002' '2003' '2004' '2005' '2006' '2007' '2008'
#  '2009' '2010' '2011' '2013' '2014' '2015' '2016' '2017' '2018' 2012 2000
#  2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2013 2014 2015
#  2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Saint Lucia 2018
# []
# Sao Tome and Principe ['2000' '2009' '2014' '2019' '2003' '2004' '2005' '2013' '2015' 2000 2009
#  2014 2003 2004 2005 2013 2015 2002 2011 2012 2016 2017 2006 2007 2008
#  2010 2018]
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2019
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Sao Tome and Principe 2018
# []
# Somalia ['2006' 2006 2007 2009 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Somalia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Somalia 2018
# []
# South Sudan ['2000' '2010' '2011' '2015' 2000 2010 2011 2015 2012 2013 2014 2016 2017
#  2018]
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2000
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2010
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2011
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2015
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2000
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2010
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2011
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2015
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2012
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2013
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2014
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2016
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2017
# []
# FEMALE.SKILL_MATH.PRIMAR South Sudan 2018
# []
# Sudan ['2000' '2010' '2014' '2011' '2016' 2000 2010 2014 2011 2012 2013 2015
#  2016 2017 2006 2007 2008 2009 2018]
# FEMALE.SKILL_MATH.PRIMAR Sudan 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Sudan 2018
# []
# Tajikistan ['2000' '2006' '2012' '2017' '2010' '2011' '2013' '2014' '2015' '2016'
#  2000 2006 2012 2017 2010 2011 2013 2014 2015 2016 2007 2008 2009 2018
#  2001 2002 2003 2004 2005]
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Tajikistan 2005
# []
# Turkmenistan ['2006' '2016' '2019' 2006 2016 2007 2008 2009 2010 2011 2012 2013 2014
#  2015 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2019
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Turkmenistan 2018
# []
# Uzbekistan ['2000' '2006' '2009' '2010' '2011' '2012' '2013' '2014' '2015' '2016'
#  '2017' '2018' 2000 2006 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018
#  2007 2008]
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2018
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Uzbekistan 2008
# []
# Venezuela (Bolivarian Republic of) ['2000' '2001' '2002' '2003' '2004' '2005' '2006' '2007' '2008' '2009'
#  '2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' 2000 2001 2002
#  2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016
#  2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2000
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2001
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2002
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2003
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2004
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2005
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Venezuela (Bolivarian Republic of) 2018
# []
# World ['2012-2020' '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014'
#  '2015' '2016' '2017' '2018' 2013 2014 2015 2016 2017 2018 2011 2012]
# FEMALE.SKILL_MATH.PRIMAR World 2012-2020
# []
# FEMALE.SKILL_MATH.PRIMAR World 2007
# []
# FEMALE.SKILL_MATH.PRIMAR World 2008
# []
# FEMALE.SKILL_MATH.PRIMAR World 2009
# []
# FEMALE.SKILL_MATH.PRIMAR World 2010
# []
# FEMALE.SKILL_MATH.PRIMAR World 2011
# []
# FEMALE.SKILL_MATH.PRIMAR World 2012
# []
# FEMALE.SKILL_MATH.PRIMAR World 2013
# []
# FEMALE.SKILL_MATH.PRIMAR World 2014
# []
# FEMALE.SKILL_MATH.PRIMAR World 2015
# []
# FEMALE.SKILL_MATH.PRIMAR World 2016
# []
# FEMALE.SKILL_MATH.PRIMAR World 2017
# []
# FEMALE.SKILL_MATH.PRIMAR World 2018
# []
# FEMALE.SKILL_MATH.PRIMAR World 2013
# []
# FEMALE.SKILL_MATH.PRIMAR World 2014
# []
# FEMALE.SKILL_MATH.PRIMAR World 2015
# []
# FEMALE.SKILL_MATH.PRIMAR World 2016
# []
# FEMALE.SKILL_MATH.PRIMAR World 2017
# []
# FEMALE.SKILL_MATH.PRIMAR World 2018
# []
# FEMALE.SKILL_MATH.PRIMAR World 2011
# []
# FEMALE.SKILL_MATH.PRIMAR World 2012
# []
# South-Eastern Asia ['2012-2020' '2005' '2006' '2007' '2008' '2009' '2010' '2011' '2012'
#  '2013' '2014' '2015' '2016' '2017' '2018' 2012 2013 2014 2015 2016 2017
#  2018 2011 2006 2007 2008 2009 2010]
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2012-2020
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2005
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2018
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2018
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR South-Eastern Asia 2006
# []
# ...
# []
# FEMALE.SKILL_MATH.PRIMAR Africa 2018
# []
# South America [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR South America 2006
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2007
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2008
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2009
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2010
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2011
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2012
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2013
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2014
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2015
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2016
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2017
# []
# FEMALE.SKILL_MATH.PRIMAR South America 2018
# []
# Western Africa [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Western Africa 2018
# []
# Central America [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Central America 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Central America 2018
# []
# Eastern Africa [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Africa 2018
# []
# Middle Africa [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Middle Africa 2018
# []
# Southern Africa [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Africa 2018
# []
# Caribbean [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Caribbean 2018
# []
# Southern Europe [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Europe 2018
# []
# Melanesia [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Melanesia 2018
# []
# Micronesia [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Micronesia 2018
# []
# Polynesia [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Polynesia 2018
# []
# Southern Asia (excluding India) [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Southern Asia (excluding India) 2018
# []
# Caucasus and Central Asia [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Caucasus and Central Asia 2018
# []
# Asia [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Asia 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Asia 2018
# []
# Eastern Europe [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Europe 2018
# []
# Eastern Asia (excluding Japan and China) [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Eastern Asia (excluding Japan and China) 2018
# []
# Libya [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Libya 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Libya 2018
# []
# Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand) 2018
# []
# Developing regions [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2006
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2007
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2008
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2015
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2016
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2017
# []
# FEMALE.SKILL_MATH.PRIMAR Developing regions 2018
# []
# Wallis and Futuna Islands [2009 2010 2011 2012 2013 2014 2015]
# FEMALE.SKILL_MATH.PRIMAR Wallis and Futuna Islands 2009
# []
# FEMALE.SKILL_MATH.PRIMAR Wallis and Futuna Islands 2010
# []
# FEMALE.SKILL_MATH.PRIMAR Wallis and Futuna Islands 2011
# []
# FEMALE.SKILL_MATH.PRIMAR Wallis and Futuna Islands 2012
# []
# FEMALE.SKILL_MATH.PRIMAR Wallis and Futuna Islands 2013
# []
# FEMALE.SKILL_MATH.PRIMAR Wallis and Futuna Islands 2014
# []
# FEMALE.SKILL_MATH.PRIMAR Wallis and Futuna Islands 2015
# []
# ODA residual [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2006
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2007
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2008
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2009
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2010
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2011
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2012
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2013
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2014
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2015
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2016
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2017
# []
# FEMALE.SKILL_MATH.PRIMAR ODA residual 2018
# []

# %%
listOfDataFrames[0]
# Out:
#    GeoAreaName Time_Detail  BOTHSEX.SKILL_READ.GRAD23
# 0  Afghanistan        2016                  22.000000
# 1    Argentina        2006                  71.727822
# 2    Argentina        2013                  76.323888
# 3    Australia        2011                  92.932800
# 4    Australia        2016                  94.486205
# 5      Bahrain        2016                  69.368335
# 6   Bangladesh        2015                  41.000000
# 7   Bangladesh        2017                  47.000000

# %%
listOfDataFrames[1]
# Out:
#    GeoAreaName Time_Detail  BOTHSEX.SKILL_READ.LOWSEC
# 0      Albania        2000                  29.644370
# 1      Albania        2009                  43.331760
# 2      Albania        2012                  47.664562
# 3      Albania        2015                  49.722730
# 4      Albania        2018                  47.764318
# 5      Algeria        2015                  21.030629
# 6   Azerbaijan        2006                  20.584980
# 7   Azerbaijan        2009                  27.211451
# 8    Argentina        2000                  56.089186
# 9    Argentina        2006                  42.136034
# 10   Argentina        2009                  48.420489
# 11   Argentina        2012                  46.435234
# 12   Argentina        2018                  47.883647
# 13   Australia        2000                  87.538588
# 14   Australia        2003                  88.156960
# 15   Australia        2006                  86.603995
# 16   Australia        2009                  85.750376
# 17   Australia        2012                  85.807536
# 18   Australia        2015                  81.932529
# 19   Australia        2018                  80.372611
# 20     Austria        2000                  85.385365
# 21     Austria        2003                  79.296716
# 22     Austria        2006                  78.483283
# 23     Austria        2009                  72.423688
# 24     Austria        2012                  80.509781
# 25     Austria        2015                  77.460341
# 26     Austria        2018                  76.376738
# 27  Bangladesh        2013                  49.000000
# 28  Bangladesh        2015                  54.000000

# %%
listOfDataFrames[2]
# Out:
#    GeoAreaName Time_Detail  FEMALE.SKILL_MATH.GRAD23
# 0  Afghanistan        2016                 22.500000
# 1      Algeria        2007                 14.867343
# 2    Argentina        2006                 57.444123
# 3    Argentina        2013                 73.766024
# 4    Australia        2003                 63.082567
# 5    Australia        2007                 69.656837
# 6    Australia        2011                 69.124687
# 7    Australia        2015                 69.294055
# 8      Bahrain        2011                 33.431320
# 9      Bahrain        2015                 42.619916

# %%
listOfDataFrames[3]
# Out:
#    GeoAreaName Time_Detail  FEMALE.SKILL_MATH.LOWSEC
# 0      Albania        2000                 40.270000
# 1      Albania        2009                 33.670000
# 2      Albania        2012                 39.700000
# 3      Albania        2015                 48.805954
# 4      Albania        2018                 59.424983
# 5      Algeria        2015                 20.749800
# 6   Azerbaijan        2006                 89.810000
# 7   Azerbaijan        2009                 51.390000
# 8    Argentina        2000                 42.520000
# 9    Argentina        2006                 34.000000
# 10   Argentina        2009                 34.400000
# 11   Argentina        2012                 30.280000
# 12   Argentina        2018                 27.213665
# 13   Australia        2000                 88.850000
# 14   Australia        2003                 86.240000
# 15   Australia        2006                 86.390000
# 16   Australia        2009                 83.690000
# 17   Australia        2012                 78.850000
# 18   Australia        2015                 78.123101
# 19   Australia        2018                 77.342295
# 20     Austria        2000                 82.610000
# 21     Austria        2003                 81.630000
# 22     Austria        2006                 77.270000
# 23     Austria        2009                 74.940000
# 24     Austria        2012                 78.810000
# 25     Austria        2015                 75.232747
# 26     Austria        2018                 78.336506
# 27     Bahrain        2003                 20.825517
# 28     Bahrain        2007                 21.055600
# 29     Bahrain        2011                 30.510134
# 30     Bahrain        2015                 43.184065
# 31  Bangladesh        2013                 29.000000
# 32  Bangladesh        2015                 52.000000
# 33     Armenia        2003                 56.269845
# 34     Armenia        2007                 63.811022
# 35     Armenia        2011                 51.413915
# 36     Armenia        2015                 51.801026

# %%
listOfDataFrames[4]
# Out:
#    GeoAreaName Time_Detail  MALE.SKILL_MATH.GRAD23
# 0  Afghanistan        2016               26.500000
# 1      Algeria        2007               13.209358
# 2    Argentina        2006               56.624427
# 3    Argentina        2013               68.402758
# 4    Australia        2003               64.380439
# 5    Australia        2007               71.636174
# 6    Australia        2011               71.207350
# 7    Australia        2015               71.120873
# 8      Bahrain        2011               34.241277
# 9      Bahrain        2015               37.270044

# %%
listOfDataFrames[5]
# Out:
#     GeoAreaName Time_Detail  BOTHSEX.SKILL_MATH.PRIMAR
# 0   Afghanistan        2013                  11.000000
# 1    Azerbaijan        2011                  46.419939
# 2     Argentina        2006                  48.594414
# 3     Argentina        2013                  55.602812
# 4     Australia        2003                  64.863053
# 5     Australia        2007                  60.785010
# 6     Australia        2011                  62.941286
# 7     Australia        2015                  64.432914
# 8       Austria        2007                  68.897266
# 9       Austria        2011                  70.434049
# 10   Bangladesh        2015                  25.000000
# 11   Bangladesh        2017                  32.000000
# 12      Armenia        2003                  42.745863
# 13      Armenia        2007                  59.995814
# 14      Armenia        2011                  40.919326
# 15      Armenia        2015                  54.563823

# %%
len(listOfDataFrames)
# Out:
# 18

# %%
listOfDataFrames_copy = listOfDataFrames

# %%
df_new = pd.merge(listOfDataFrames[0], listOfDataFrames[1],  how='left', left_on=['GeoAreaName','Time_Detail'], right_on = ['GeoAreaName','Time_Detail'])
for i in range(2,18):
  df_new = pd.merge(df_new, listOfDataFrames[i],  how='left', left_on=['GeoAreaName','Time_Detail'], right_on = ['GeoAreaName','Time_Detail'])

# %%
df_new
# Out:
#                   GeoAreaName  ... FEMALE.SKILL_MATH.PRIMAR
# 0                 Afghanistan  ...                      NaN
# 1                   Argentina  ...                47.933275
# 2                   Argentina  ...                52.527277
# 3                   Australia  ...                61.604058
# 4                   Australia  ...                      NaN
# ..                        ...  ...                      ...
# 169  United States of America  ...                      NaN
# 170  United States of America  ...                      NaN
# 171              Burkina Faso  ...                17.900000
# 172                   Uruguay  ...                73.388436
# 173                   Uruguay  ...                67.054896
#
# [174 rows x 20 columns]

# %%
df_new.columns
# Out:
# Index(['GeoAreaName', 'Time_Detail', 'BOTHSEX.SKILL_READ.GRAD23',
#        'BOTHSEX.SKILL_READ.LOWSEC', 'FEMALE.SKILL_MATH.GRAD23',
#        'FEMALE.SKILL_MATH.LOWSEC', 'MALE.SKILL_MATH.GRAD23',
#        'BOTHSEX.SKILL_MATH.PRIMAR', 'MALE.SKILL_READ.GRAD23',
#        'MALE.SKILL_MATH.LOWSEC', 'FEMALE.SKILL_READ.LOWSEC',
#        'BOTHSEX.SKILL_READ.PRIMAR', 'FEMALE.SKILL_READ.GRAD23',
#        'BOTHSEX.SKILL_MATH.LOWSEC', 'MALE.SKILL_READ.PRIMAR',
#        'FEMALE.SKILL_READ.PRIMAR', 'BOTHSEX.SKILL_MATH.GRAD23',
#        'MALE.SKILL_MATH.PRIMAR', 'MALE.SKILL_READ.LOWSEC',
#        'FEMALE.SKILL_MATH.PRIMAR'],
#       dtype='object')

# %%
df_origCols = df_new[['GeoAreaName','Time_Detail']]

df_dataOnly = df_new[['BOTHSEX.SKILL_READ.GRAD23',
       'BOTHSEX.SKILL_READ.LOWSEC', 'FEMALE.SKILL_MATH.GRAD23',
       'FEMALE.SKILL_MATH.LOWSEC', 'MALE.SKILL_MATH.GRAD23',
       'BOTHSEX.SKILL_MATH.PRIMAR', 'MALE.SKILL_READ.GRAD23',
       'MALE.SKILL_MATH.LOWSEC', 'FEMALE.SKILL_READ.LOWSEC',
       'BOTHSEX.SKILL_READ.PRIMAR', 'FEMALE.SKILL_READ.GRAD23',
       'BOTHSEX.SKILL_MATH.LOWSEC', 'MALE.SKILL_READ.PRIMAR',
       'FEMALE.SKILL_READ.PRIMAR', 'BOTHSEX.SKILL_MATH.GRAD23',
       'MALE.SKILL_MATH.PRIMAR', 'MALE.SKILL_READ.LOWSEC',
       'FEMALE.SKILL_MATH.PRIMAR']]

# %%
df_origCols
# Out:
#                   GeoAreaName Time_Detail
# 0                 Afghanistan        2016
# 1                   Argentina        2006
# 2                   Argentina        2013
# 3                   Australia        2011
# 4                   Australia        2016
# ..                        ...         ...
# 169  United States of America        2011
# 170  United States of America        2016
# 171              Burkina Faso        2014
# 172                   Uruguay        2006
# 173                   Uruguay        2013
#
# [174 rows x 2 columns]

# %%
df_dataOnly
# Out:
#      BOTHSEX.SKILL_READ.GRAD23  ...  FEMALE.SKILL_MATH.PRIMAR
# 0                    22.000000  ...                       NaN
# 1                    71.727822  ...                 47.933275
# 2                    76.323888  ...                 52.527277
# 3                    92.932800  ...                 61.604058
# 4                    94.486205  ...                       NaN
# ..                         ...  ...                       ...
# 169                  97.517359  ...                       NaN
# 170                  96.094080  ...                       NaN
# 171                  35.590000  ...                 17.900000
# 172                  75.350014  ...                 73.388436
# 173                  79.785388  ...                 67.054896
#
# [174 rows x 18 columns]

# %%
dataColNames = df_dataOnly.columns
X = df_dataOnly.to_numpy()

# %%
X
# Out:
# array([[22.        ,         nan, 22.5       , ...,         nan,
#                 nan,         nan],
#        [71.72782174, 42.13603413, 57.44412343, ..., 50.83023243,
#         33.1       , 47.93327546],
#        [76.32388756,         nan, 73.76602371, ..., 58.62759568,
#                 nan, 52.52727731],
#        ...,
#        [35.59      ,         nan, 56.79      , ..., 24.12      ,
#                 nan, 17.9       ],
#        [75.35001415, 53.36259043, 69.05911158, ..., 73.88288705,
#         45.26      , 73.38843629],
#        [79.78538797,         nan, 76.90927529, ..., 69.4939529 ,
#                 nan, 67.05489614]])

# %%
dataColNames
# Out:
# Index(['BOTHSEX.SKILL_READ.GRAD23', 'BOTHSEX.SKILL_READ.LOWSEC',
#        'FEMALE.SKILL_MATH.GRAD23', 'FEMALE.SKILL_MATH.LOWSEC',
#        'MALE.SKILL_MATH.GRAD23', 'BOTHSEX.SKILL_MATH.PRIMAR',
#        'MALE.SKILL_READ.GRAD23', 'MALE.SKILL_MATH.LOWSEC',
#        'FEMALE.SKILL_READ.LOWSEC', 'BOTHSEX.SKILL_READ.PRIMAR',
#        'FEMALE.SKILL_READ.GRAD23', 'BOTHSEX.SKILL_MATH.LOWSEC',
#        'MALE.SKILL_READ.PRIMAR', 'FEMALE.SKILL_READ.PRIMAR',
#        'BOTHSEX.SKILL_MATH.GRAD23', 'MALE.SKILL_MATH.PRIMAR',
#        'MALE.SKILL_READ.LOWSEC', 'FEMALE.SKILL_MATH.PRIMAR'],
#       dtype='object')

# %%
# knn imputation

import numpy as np
from sklearn.impute import KNNImputer
nan = np.nan
X = df_dataOnly.to_numpy()
imputer = KNNImputer(n_neighbors=3, weights="uniform")
df_imputeDataOnly = imputer.fit_transform(X)

# %%
df_imputeDataOnly = pd.DataFrame(data=df_imputeDataOnly,columns=dataColNames)

# %%
df_imputeDataOnly
# Out:
#      BOTHSEX.SKILL_READ.GRAD23  ...  FEMALE.SKILL_MATH.PRIMAR
# 0                    22.000000  ...                 14.478434
# 1                    71.727822  ...                 47.933275
# 2                    76.323888  ...                 52.527277
# 3                    92.932800  ...                 61.604058
# 4                    94.486205  ...                 68.819378
# ..                         ...  ...                       ...
# 169                  97.517359  ...                 70.300225
# 170                  96.094080  ...                 68.819378
# 171                  35.590000  ...                 17.900000
# 172                  75.350014  ...                 73.388436
# 173                  79.785388  ...                 67.054896
#
# [174 rows x 18 columns]

# %%
df_imputed = pd.concat([df_origCols, df_imputeDataOnly], axis=1)

# %%
df_imputed
# Out:
#                   GeoAreaName  ... FEMALE.SKILL_MATH.PRIMAR
# 0                 Afghanistan  ...                14.478434
# 1                   Argentina  ...                47.933275
# 2                   Argentina  ...                52.527277
# 3                   Australia  ...                61.604058
# 4                   Australia  ...                68.819378
# ..                        ...  ...                      ...
# 169  United States of America  ...                70.300225
# 170  United States of America  ...                68.819378
# 171              Burkina Faso  ...                17.900000
# 172                   Uruguay  ...                73.388436
# 173                   Uruguay  ...                67.054896
#
# [174 rows x 20 columns]

# %%
df_imputed

# %%
df_imputed.to_csv(data_path+"df_imputed.csv")
