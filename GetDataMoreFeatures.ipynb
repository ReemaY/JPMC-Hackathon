# %%
import pandas as pd
import numpy as np
from google.colab import drive

drive.mount('/content/gdrive')
root_path = "gdrive/My Drive/JPMC_Hackathon/"
data_path = root_path + "data/"
# Out:
# Mounted at /content/gdrive

# %%
raw_data = pd.read_csv(data_path+"Goal4.csv")

df = pd.read_csv(data_path+"Goal4.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,9,16,17,19,21,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Goal Target Indicator  ... Unnamed: 49 Unnamed: 50  Unnamed: 51
# 0          4    4.1     4.1.1  ...         NaN         NaN          NaN
# 1          4    4.1     4.1.1  ...         NaN         NaN          NaN
# 2          4    4.1     4.1.1  ...         NaN         NaN          NaN
# 3          4    4.1     4.1.1  ...         NaN         NaN          NaN
# 4          4    4.1     4.1.1  ...         NaN         NaN          NaN
# ...      ...    ...       ...  ...         ...         ...          ...
# 191757     4    4.c     4.c.1  ...         NaN         NaN          NaN
# 191758     4    4.c     4.c.1  ...         NaN         NaN          NaN
# 191759     4    4.c     4.c.1  ...         NaN         NaN          NaN
# 191760     4    4.c     4.c.1  ...         NaN         NaN          NaN
# 191761     4    4.c     4.c.1  ...         NaN         NaN          NaN
#
# [191762 rows x 52 columns]

# %%
df['Target'].unique()
# Out:
# array([4.1, 4.2, 4.3, 4.4, 4.5, '4.5', '4.6', '4.a', '4.b', '4.c'],
#       dtype=object)

# %%
len(df['SeriesDescription'].unique())
# Out:
# 29

# %%
df['SeriesDescription'].unique()
# Out:
# array(['Proportion of children and young people achieving a minimum proficiency level in reading and mathematics (%)',
#        'Completion rate, by sex, location, wealth quintile and education level (%)',
#        'Proportion of children aged 36−59 months who are developmentally on track in at least three of the following domains: literacy-numeracy, physical development, social-emotional development, and learning (% of children aged 36-59 months)',
#        'Participation rate in organized learning (one year before the official primary entry age), by sex (%)',
#        'Participation rate in formal and non-formal education and training, by sex (%)',
#        'Proportion of youth and adults with information and communications technology (ICT) skills, by sex and type of skill (%)',
#        'Adjusted gender parity index for completion rate, by sex, location, wealth quintile and education level',
#        'Adjusted location parity index for completion rate, by sex, location, wealth quintile and education level',
#        'Adjusted wealth parity index for completion rate, by sex, location, wealth quintile and education level',
#        'Gender parity index for youth/adults with information and communications technology (ICT) skills, by type of skill (ratio)',
#        'Gender parity index for participation rate in formal and non-formal education and training (ratio)',
#        'Gender parity index for participation rate in organized learning (one year before the official primary entry age), (ratio)',
#        'Gender parity index of trained teachers, by education level (ratio)',
#        'Immigration status parity index for achieving at least a fixed level of proficiency in functional skills, by numeracy/literacy skills (ratio)',
#        'Language test parity index for achievement (ratio)',
#        'Native parity index for achievement (ratio)',
#        'Gender parity index for achievement (ratio)',
#        'Rural to urban parity index for achievement (ratio)',
#        'Low to high socio-economic parity status index for achievement (ratio)',
#        'Proportion of population achieving at least a fixed level of proficiency in functional skills, by sex, age and type of skill (%)',
#        'Schools with basic handwashing facilities, by education level (%)',
#        'Schools with access to\xa0computers for pedagogical purposes, by education level (%)',
#        'Schools with access to\xa0electricity, by education level (%)',
#        'Schools with access to basic drinking water, by education level (%)',
#        'Schools with access to the internet for pedagogical purposes, by education level (%)',
#        'Schools with access to\xa0access to single-sex basic sanitation, by education level (%)',
#        'Proportion of schools with access to adapted infrastructure and materials for students with disabilities, by education level (%)',
#        'Total official flows for scholarships, by recipient countries (millions of constant 2018 United States dollars)',
#        'Proportion of teachers who have received at least the minimum organized teacher training (e.g. pedagogical training) pre-service or in-service required for teaching at the relevant level in a given country, by sex and education level (%)'],
#       dtype=object)

# %%
len(df['Indicator'].unique())
# Out:
# 11

# %%
df['Indicator'].unique()
# Out:
# array(['4.1.1', '4.1.2', '4.2.1', '4.2.2', '4.3.1', '4.4.1', '4.5.1',
#        '4.6.1', '4.a.1', '4.b.1', '4.c.1'], dtype=object)

# %%
len(df['SeriesCode'].unique())
# Out:
# 29

# %%
df.describe()
# Out:
#            Goal    GeoAreaCode  ...  Unnamed: 50  Unnamed: 51
# count  191762.0  191762.000000  ...          0.0          0.0
# mean        4.0     396.544002  ...          NaN          NaN
# std         0.0     250.320400  ...          NaN          NaN
# min         4.0       1.000000  ...          NaN          NaN
# 25%         4.0     188.000000  ...          NaN          NaN
# 50%         4.0     372.000000  ...          NaN          NaN
# 75%         4.0     600.000000  ...          NaN          NaN
# max         4.0     921.000000  ...          NaN          NaN
#
# [8 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'TimePeriod', 'Value', 'Time_Detail',
#        'TimeCoverage', 'UpperBound', 'LowerBound', 'BasePeriod', 'Source',
#        'GeoInfoUrl', 'FootNote', 'Age', 'Education level', 'Location',
#        'Nature', 'Quantile', 'Reporting Type', 'Sex', 'Type of skill', 'Units',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
#        'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50', 'Unnamed: 51'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
       'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
       'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
       'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
       'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
       'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
       'Unnamed: 50', 'Unnamed: 51'],axis=1)

# %%
df = df.drop(['Goal','Target','Indicator','TimePeriod'],axis=1)

# %%
df.describe()
# Out:
#          GeoAreaCode          Value  ...  BasePeriod  GeoInfoUrl
# count  191762.000000  179570.000000  ...      2276.0         0.0
# mean      396.544002      41.595042  ...      2018.0         NaN
# std       250.320400      41.230603  ...         0.0         NaN
# min         1.000000       0.000000  ...      2018.0         NaN
# 25%       188.000000       1.001600  ...      2018.0         NaN
# 50%       372.000000      34.134145  ...      2018.0         NaN
# 75%       600.000000      83.482728  ...      2018.0         NaN
# max       921.000000    1632.065770  ...      2018.0         NaN
#
# [8 rows x 7 columns]

# %%
len(df)
# Out:
# 191762

# %%
df.isna().sum()
# Out:
# SeriesCode                0
# SeriesDescription         0
# GeoAreaCode               0
# GeoAreaName               0
# Value                 12192
# Time_Detail               0
# TimeCoverage         191762
# UpperBound           191762
# LowerBound           191762
# BasePeriod           189486
# Source                    0
# GeoInfoUrl           191762
# FootNote             176950
# Age                  191281
# Education level       17879
# Location              78911
# Nature                    0
# Quantile              55387
# Reporting Type            0
# Sex                   48829
# Type of skill        175898
# Units                     0
# dtype: int64

# %%
df = df.drop(['TimeCoverage','UpperBound','LowerBound','GeoInfoUrl'],axis=1)

# %%
df = df.drop(['GeoAreaCode','BasePeriod','Age','FootNote','Source','Reporting Type','Units'],axis=1)

# %%
df = df.drop(['Nature'],axis=1)

# %%
#df = df.drop(['Quantile'],axis=1)

# %%
#df = df.drop(['Location'],axis=1)

# %%
df_afghanistan = df[(df.GeoAreaName == 'Afghanistan')]
df_afghanistan
# Out:
#         Goal Target Indicator  ... Unnamed: 49 Unnamed: 50 Unnamed: 51
# 0          4    4.1     4.1.1  ...         NaN         NaN         NaN
# 1          4    4.1     4.1.1  ...         NaN         NaN         NaN
# 2          4    4.1     4.1.1  ...         NaN         NaN         NaN
# 3          4    4.1     4.1.1  ...         NaN         NaN         NaN
# 4          4    4.1     4.1.1  ...         NaN         NaN         NaN
# ...      ...    ...       ...  ...         ...         ...         ...
# 175972     4    4.b     4.b.1  ...         NaN         NaN         NaN
# 175973     4    4.b     4.b.1  ...         NaN         NaN         NaN
# 175974     4    4.b     4.b.1  ...         NaN         NaN         NaN
# 175975     4    4.b     4.b.1  ...         NaN         NaN         NaN
# 175976     4    4.b     4.b.1  ...         NaN         NaN         NaN
#
# [649 rows x 40 columns]

# %%
df_afghanistan['Time_Detail'].unique()
# Out:
# array([2013, 2016, 2011, 2015, '2011', '2015', 2017, 2018, 2006, 2007,
#        2008, 2009, 2010, 2012, 2014], dtype=object)

# %%
len(df_afghanistan)
# Out:
# 649

# %%
df_afghanistan
# Out:
#         Goal Target Indicator  ... Unnamed: 49 Unnamed: 50 Unnamed: 51
# 0          4    4.1     4.1.1  ...         NaN         NaN         NaN
# 1          4    4.1     4.1.1  ...         NaN         NaN         NaN
# 2          4    4.1     4.1.1  ...         NaN         NaN         NaN
# 3          4    4.1     4.1.1  ...         NaN         NaN         NaN
# 4          4    4.1     4.1.1  ...         NaN         NaN         NaN
# ...      ...    ...       ...  ...         ...         ...         ...
# 175972     4    4.b     4.b.1  ...         NaN         NaN         NaN
# 175973     4    4.b     4.b.1  ...         NaN         NaN         NaN
# 175974     4    4.b     4.b.1  ...         NaN         NaN         NaN
# 175975     4    4.b     4.b.1  ...         NaN         NaN         NaN
# 175976     4    4.b     4.b.1  ...         NaN         NaN         NaN
#
# [649 rows x 40 columns]

# %%
df_afghanistan['SeriesCode'].unique()
# Out:
# array(['SE_TOT_PRFL', 'SE_TOT_CPLR', 'SE_AGP_CPRA', 'SE_ALP_CPLR',
#        'SE_AWP_CPRA', 'SE_TOT_GPI', 'SE_TOT_RUPI', 'SE_ACC_HNDWSH',
#        'SE_ACS_ELECT', 'SE_ACS_H2O', 'SE_ACS_SANIT', 'DC_TOF_SCHIPSL'],
#       dtype=object)

# %%
df['GeoAreaName'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Azerbaijan', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Armenia',
#        'Belgium', 'Bhutan', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'Belize', 'Brunei Darussalam', 'Bulgaria', 'Burundi',
#        'Belarus', 'Cambodia', 'Cameroon', 'Canada', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo',
#        'Democratic Republic of the Congo', 'Costa Rica', 'Croatia',
#        'Cuba', 'Cyprus', 'Czechia', 'Benin', 'Denmark',
#        'Dominican Republic', 'Ecuador', 'El Salvador', 'Estonia',
#        'Finland', 'France', 'Gabon', 'Georgia', 'Gambia',
#        'State of Palestine', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Honduras', 'China, Hong Kong Special Administrative Region',
#        'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran (Islamic Republic of)', 'Ireland', 'Israel', 'Italy',
#        "Côte d'Ivoire", 'Japan', 'Kazakhstan', 'Jordan', 'Kenya',
#        "Democratic People's Republic of Korea", 'Republic of Korea',
#        'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic",
#        'Lebanon', 'Lesotho', 'Latvia', 'Liechtenstein', 'Lithuania',
#        'Luxembourg', 'China, Macao Special Administrative Region',
#        'Madagascar', 'Malawi', 'Malaysia', 'Malta', 'Mauritania',
#        'Mauritius', 'Mexico', 'Mongolia', 'Republic of Moldova',
#        'Montenegro', 'Morocco', 'Mozambique', 'Oman', 'Namibia',
#        'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Norway',
#        'Pakistan', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Qatar', 'Romania', 'Russian Federation',
#        'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'Slovakia', 'Viet Nam', 'Slovenia', 'South Africa',
#        'Zimbabwe', 'Spain', 'Suriname', 'Eswatini', 'Sweden',
#        'Switzerland', 'Syrian Arab Republic', 'Thailand', 'Togo',
#        'Trinidad and Tobago', 'United Arab Emirates', 'Tunisia', 'Turkey',
#        'Uganda', 'Ukraine', 'North Macedonia', 'Egypt',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United Republic of Tanzania', 'United States of America',
#        'Burkina Faso', 'Uruguay', 'Yemen', 'Zambia', 'Angola', 'Barbados',
#        'Bolivia (Plurinational State of)', 'Myanmar',
#        'Central African Republic', 'Sri Lanka', 'Equatorial Guinea',
#        'Ethiopia', 'Fiji', 'Djibouti', 'Guinea', 'Guyana', 'Haiti',
#        'Iraq', 'Jamaica', 'Liberia', 'Maldives', 'Mali', 'Nepal',
#        'Vanuatu', 'Nigeria', 'Guinea-Bissau', 'Timor-Leste',
#        'Puerto Rico', 'Rwanda', 'Saint Lucia', 'Sao Tome and Principe',
#        'Somalia', 'South Sudan', 'Sudan', 'Tajikistan', 'Turkmenistan',
#        'Uzbekistan', 'Venezuela (Bolivarian Republic of)', 'World',
#        'South-Eastern Asia', 'Western Asia', 'Sub-Saharan Africa',
#        'Kiribati', 'Marshall Islands',
#        'Small island developing States (SIDS)', 'Tonga', 'Samoa',
#        'Oceania', 'Northern Africa', 'Northern America',
#        'Antigua and Barbuda', 'Southern Asia', 'Bahamas',
#        'Australia and New Zealand', 'Bermuda',
#        'Central and Southern Asia', 'Solomon Islands',
#        'British Virgin Islands', 'Cabo Verde', 'Central Asia', 'Europe',
#        'Cook Islands', 'Least Developed Countries (LDCs)', 'Dominica',
#        'Eritrea', 'Gibraltar', 'Grenada', 'Holy See',
#        'Latin America and the Caribbean',
#        'Landlocked developing countries (LLDCs)', 'Montserrat',
#        'Europe and Northern America', 'Nauru', 'Aruba',
#        'Sint Maarten (Dutch part)',
#        'Oceania (exc. Australia and New Zealand)', 'Niue',
#        'Micronesia (Federated States of)', 'Palau', 'Papua New Guinea',
#        'Saint Kitts and Nevis', 'Anguilla',
#        'Saint Vincent and the Grenadines', 'San Marino',
#        'Northern Africa and Western Asia',
#        'Eastern and South-Eastern Asia', 'Tokelau', 'Tuvalu', 'Andorra',
#        'Kosovo', 'Curaçao', 'Cayman Islands', 'Monaco',
#        'Turks and Caicos Islands', 'Eastern Asia', 'Africa',
#        'South America', 'Western Africa', 'Central America',
#        'Eastern Africa', 'Middle Africa', 'Southern Africa', 'Caribbean',
#        'Southern Europe', 'Melanesia', 'Micronesia', 'Polynesia',
#        'Southern Asia (excluding India)', 'Caucasus and Central Asia',
#        'Asia', 'Eastern Europe',
#        'Eastern Asia (excluding Japan and China)', 'Libya',
#        'Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand)',
#        'Developing regions', 'Wallis and Futuna Islands', 'ODA residual'],
#       dtype=object)

# %%
df_afghanistan[df_afghanistan['SeriesCode'] == 'SE_TOT_PRFL']
# Out:
#     SeriesCode  ... Type of skill
# 0  SE_TOT_PRFL  ...    SKILL_MATH
# 1  SE_TOT_PRFL  ...    SKILL_READ
# 2  SE_TOT_PRFL  ...    SKILL_READ
# 3  SE_TOT_PRFL  ...    SKILL_READ
# 4  SE_TOT_PRFL  ...    SKILL_READ
# 5  SE_TOT_PRFL  ...    SKILL_MATH
# 6  SE_TOT_PRFL  ...    SKILL_MATH
# 7  SE_TOT_PRFL  ...    SKILL_MATH
#
# [8 rows x 11 columns]

# %%
df_afghanistan.columns
# Out:
# Index(['SeriesCode', 'SeriesDescription', 'GeoAreaName', 'Value',
#        'Time_Detail', 'Education level', 'Location', 'Nature', 'Quantile',
#        'Sex', 'Type of skill'],
#       dtype='object')

# %%
pd.set_option('max_rows', 99999)
pd.set_option('max_colwidth', 400)
pd.describe_option('max_colwidth')
# Out:
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 400]

# %%
# later on we can include location and quantile
feat_mat = df.fillna("NA").groupby(['Sex','Type of skill','Education level',"Location","Quantile"]).size().reset_index(name='Freq')

# %%
feat_mat
# Out:
#          Sex Type of skill Education level Location Quantile  Freq
# 0    BOTHSEX          ARSP              NA       NA       NA   285
# 1    BOTHSEX          CMFL              NA       NA       NA   301
# 2    BOTHSEX          COPA              NA       NA       NA   241
# 3    BOTHSEX         EMAIL              NA       NA       NA   177
# 4    BOTHSEX          EPRS              NA       NA       NA   311
# 5    BOTHSEX          INST              NA       NA       NA   180
# 6    BOTHSEX          LITE              NA       NA       NA    57
# 7    BOTHSEX            NA          LOWSEC  ALLAREA       Q1   644
# 8    BOTHSEX            NA          LOWSEC  ALLAREA       Q2   644
# 9    BOTHSEX            NA          LOWSEC  ALLAREA       Q3   644
# 10   BOTHSEX            NA          LOWSEC  ALLAREA       Q4   644
# 11   BOTHSEX            NA          LOWSEC  ALLAREA       Q5   644
# 12   BOTHSEX            NA          LOWSEC  ALLAREA       _T  1342
# 13   BOTHSEX            NA          LOWSEC       NA       NA   758
# 14   BOTHSEX            NA          LOWSEC       NA       Q1   423
# 15   BOTHSEX            NA          LOWSEC       NA       Q2   423
# 16   BOTHSEX            NA          LOWSEC       NA       Q3   423
# 17   BOTHSEX            NA          LOWSEC       NA       Q4   423
# 18   BOTHSEX            NA          LOWSEC       NA       Q5   423
# 19   BOTHSEX            NA          LOWSEC       NA       _T   659
# 20   BOTHSEX            NA          LOWSEC    RURAL       Q1   423
# 21   BOTHSEX            NA          LOWSEC    RURAL       Q2   423
# 22   BOTHSEX            NA          LOWSEC    RURAL       Q3   423
# 23   BOTHSEX            NA          LOWSEC    RURAL       Q4   423
# 24   BOTHSEX            NA          LOWSEC    RURAL       Q5   423
# 25   BOTHSEX            NA          LOWSEC    RURAL       _T  1082
# 26   BOTHSEX            NA          LOWSEC    URBAN       Q1   446
# 27   BOTHSEX            NA          LOWSEC    URBAN       Q2   446
# 28   BOTHSEX            NA          LOWSEC    URBAN       Q3   446
# 29   BOTHSEX            NA          LOWSEC    URBAN       Q4   446
# 30   BOTHSEX            NA          LOWSEC    URBAN       Q5   446
# 31   BOTHSEX            NA          LOWSEC    URBAN       _T  1132
# 32   BOTHSEX            NA              NA       NA       NA  2436
# 33   BOTHSEX            NA          PREPRI       NA       NA  1018
# 34   BOTHSEX            NA          PRIMAR  ALLAREA       Q1   522
# 35   BOTHSEX            NA          PRIMAR  ALLAREA       Q2   522
# 36   BOTHSEX            NA          PRIMAR  ALLAREA       Q3   522
# 37   BOTHSEX            NA          PRIMAR  ALLAREA       Q4   522
# 38   BOTHSEX            NA          PRIMAR  ALLAREA       Q5   522
# 39   BOTHSEX            NA          PRIMAR  ALLAREA       _T  1098
# 40   BOTHSEX            NA          PRIMAR       NA       NA  1458
# 41   BOTHSEX            NA          PRIMAR       NA       Q1   423
# 42   BOTHSEX            NA          PRIMAR       NA       Q2   423
# 43   BOTHSEX            NA          PRIMAR       NA       Q3   423
# 44   BOTHSEX            NA          PRIMAR       NA       Q4   423
# 45   BOTHSEX            NA          PRIMAR       NA       Q5   423
# 46   BOTHSEX            NA          PRIMAR       NA       _T   549
# 47   BOTHSEX            NA          PRIMAR    RURAL       Q1   423
# 48   BOTHSEX            NA          PRIMAR    RURAL       Q2   423
# 49   BOTHSEX            NA          PRIMAR    RURAL       Q3   423
# 50   BOTHSEX            NA          PRIMAR    RURAL       Q4   423
# 51   BOTHSEX            NA          PRIMAR    RURAL       Q5   423
# 52   BOTHSEX            NA          PRIMAR    RURAL       _T   972
# 53   BOTHSEX            NA          PRIMAR    URBAN       Q1   446
# 54   BOTHSEX            NA          PRIMAR    URBAN       Q2   446
# 55   BOTHSEX            NA          PRIMAR    URBAN       Q3   446
# 56   BOTHSEX            NA          PRIMAR    URBAN       Q4   446
# 57   BOTHSEX            NA          PRIMAR    URBAN       Q5   446
# 58   BOTHSEX            NA          PRIMAR    URBAN       _T  1019
# 59   BOTHSEX            NA          SECOND       NA       NA   934
# 60   BOTHSEX            NA          UPPSEC  ALLAREA       Q1   641
# 61   BOTHSEX            NA          UPPSEC  ALLAREA       Q2   641
# 62   BOTHSEX            NA          UPPSEC  ALLAREA       Q3   641
# 63   BOTHSEX            NA          UPPSEC  ALLAREA       Q4   641
# 64   BOTHSEX            NA          UPPSEC  ALLAREA       Q5   641
# 65   BOTHSEX            NA          UPPSEC  ALLAREA       _T  1336
# 66   BOTHSEX            NA          UPPSEC       NA       NA   646
# 67   BOTHSEX            NA          UPPSEC       NA       Q1   420
# 68   BOTHSEX            NA          UPPSEC       NA       Q2   420
# 69   BOTHSEX            NA          UPPSEC       NA       Q3   420
# 70   BOTHSEX            NA          UPPSEC       NA       Q4   420
# 71   BOTHSEX            NA          UPPSEC       NA       Q5   420
# 72   BOTHSEX            NA          UPPSEC       NA       _T   656
# 73   BOTHSEX            NA          UPPSEC    RURAL       Q1   420
# 74   BOTHSEX            NA          UPPSEC    RURAL       Q2   420
# 75   BOTHSEX            NA          UPPSEC    RURAL       Q3   420
# 76   BOTHSEX            NA          UPPSEC    RURAL       Q4   420
# 77   BOTHSEX            NA          UPPSEC    RURAL       Q5   420
# 78   BOTHSEX            NA          UPPSEC    RURAL       _T  1076
# 79   BOTHSEX            NA          UPPSEC    URBAN       Q1   443
# 80   BOTHSEX            NA          UPPSEC    URBAN       Q2   443
# 81   BOTHSEX            NA          UPPSEC    URBAN       Q3   443
# 82   BOTHSEX            NA          UPPSEC    URBAN       Q4   443
# 83   BOTHSEX            NA          UPPSEC    URBAN       Q5   443
# 84   BOTHSEX            NA          UPPSEC    URBAN       _T  1126
# 85   BOTHSEX          NUME              NA       NA       NA    36
# 86   BOTHSEX          PCPR              NA       NA       NA   296
# 87   BOTHSEX    SKILL_MATH          GRAD23       NA       NA   153
# 88   BOTHSEX    SKILL_MATH          LOWSEC       NA       NA   437
# 89   BOTHSEX    SKILL_MATH          PRIMAR       NA       NA   115
# 90   BOTHSEX    SKILL_READ          GRAD23       NA       NA   174
# 91   BOTHSEX    SKILL_READ          LOWSEC       NA       NA   413
# 92   BOTHSEX    SKILL_READ          PRIMAR       NA       NA   105
# 93   BOTHSEX          SOFT              NA       NA       NA   255
# 94   BOTHSEX          TRAF              NA       NA       NA   303
# 95    FEMALE          ARSP              NA       NA       NA   226
# 96    FEMALE          CMFL              NA       NA       NA   211
# 97    FEMALE          COPA              NA       NA       NA   195
# 98    FEMALE         EMAIL              NA       NA       NA   112
# 99    FEMALE          EPRS              NA       NA       NA   246
# 100   FEMALE          INST              NA       NA       NA   146
# 101   FEMALE          LITE              NA       NA       NA    37
# 102   FEMALE            NA          LOWSEC  ALLAREA       Q1   438
# 103   FEMALE            NA          LOWSEC  ALLAREA       Q2   438
# 104   FEMALE            NA          LOWSEC  ALLAREA       Q3   438
# 105   FEMALE            NA          LOWSEC  ALLAREA       Q4   438
# 106   FEMALE            NA          LOWSEC  ALLAREA       Q5   438
# 107   FEMALE            NA          LOWSEC  ALLAREA       _T  1136
# 108   FEMALE            NA          LOWSEC       NA       NA   700
# 109   FEMALE            NA          LOWSEC       NA       Q1   423
# 110   FEMALE            NA          LOWSEC       NA       Q2   423
# 111   FEMALE            NA          LOWSEC       NA       Q3   423
# 112   FEMALE            NA          LOWSEC       NA       Q4   423
# 113   FEMALE            NA          LOWSEC       NA       Q5   423
# 114   FEMALE            NA          LOWSEC       NA       _T   446
# 115   FEMALE            NA          LOWSEC    RURAL       Q1   423
# 116   FEMALE            NA          LOWSEC    RURAL       Q2   423
# 117   FEMALE            NA          LOWSEC    RURAL       Q3   423
# 118   FEMALE            NA          LOWSEC    RURAL       Q4   423
# 119   FEMALE            NA          LOWSEC    RURAL       Q5   423
# 120   FEMALE            NA          LOWSEC    RURAL       _T   869
# 121   FEMALE            NA          LOWSEC    URBAN       Q1   446
# 122   FEMALE            NA          LOWSEC    URBAN       Q2   446
# 123   FEMALE            NA          LOWSEC    URBAN       Q3   446
# 124   FEMALE            NA          LOWSEC    URBAN       Q4   446
# 125   FEMALE            NA          LOWSEC    URBAN       Q5   446
# 126   FEMALE            NA          LOWSEC    URBAN       _T   915
# 127   FEMALE            NA              NA       NA       NA  2349
# 128   FEMALE            NA          PREPRI       NA       NA   935
# 129   FEMALE            NA          PRIMAR  ALLAREA       Q1   438
# 130   FEMALE            NA          PRIMAR  ALLAREA       Q2   438
# 131   FEMALE            NA          PRIMAR  ALLAREA       Q3   438
# 132   FEMALE            NA          PRIMAR  ALLAREA       Q4   438
# 133   FEMALE            NA          PRIMAR  ALLAREA       Q5   438
# 134   FEMALE            NA          PRIMAR  ALLAREA       _T  1014
# 135   FEMALE            NA          PRIMAR       NA       NA  1304
# 136   FEMALE            NA          PRIMAR       NA       Q1   423
# 137   FEMALE            NA          PRIMAR       NA       Q2   423
# 138   FEMALE            NA          PRIMAR       NA       Q3   423
# 139   FEMALE            NA          PRIMAR       NA       Q4   423
# 140   FEMALE            NA          PRIMAR       NA       Q5   423
# 141   FEMALE            NA          PRIMAR       NA       _T   446
# 142   FEMALE            NA          PRIMAR    RURAL       Q1   423
# 143   FEMALE            NA          PRIMAR    RURAL       Q2   423
# 144   FEMALE            NA          PRIMAR    RURAL       Q3   423
# 145   FEMALE            NA          PRIMAR    RURAL       Q4   423
# 146   FEMALE            NA          PRIMAR    RURAL       Q5   423
# 147   FEMALE            NA          PRIMAR    RURAL       _T   869
# 148   FEMALE            NA          PRIMAR    URBAN       Q1   446
# 149   FEMALE            NA          PRIMAR    URBAN       Q2   446
# 150   FEMALE            NA          PRIMAR    URBAN       Q3   446
# 151   FEMALE            NA          PRIMAR    URBAN       Q4   446
# 152   FEMALE            NA          PRIMAR    URBAN       Q5   446
# 153   FEMALE            NA          PRIMAR    URBAN       _T   915
# 154   FEMALE            NA          SECOND       NA       NA   834
# 155   FEMALE            NA          UPPSEC  ALLAREA       Q1   435
# 156   FEMALE            NA          UPPSEC  ALLAREA       Q2   435
# 157   FEMALE            NA          UPPSEC  ALLAREA       Q3   435
# 158   FEMALE            NA          UPPSEC  ALLAREA       Q4   435
# 159   FEMALE            NA          UPPSEC  ALLAREA       Q5   435
# 160   FEMALE            NA          UPPSEC  ALLAREA       _T  1130
# 161   FEMALE            NA          UPPSEC       NA       NA   584
# 162   FEMALE            NA          UPPSEC       NA       Q1   420
# 163   FEMALE            NA          UPPSEC       NA       Q2   420
# 164   FEMALE            NA          UPPSEC       NA       Q3   420
# 165   FEMALE            NA          UPPSEC       NA       Q4   420
# 166   FEMALE            NA          UPPSEC       NA       Q5   420
# 167   FEMALE            NA          UPPSEC       NA       _T   443
# 168   FEMALE            NA          UPPSEC    RURAL       Q1   420
# 169   FEMALE            NA          UPPSEC    RURAL       Q2   420
# 170   FEMALE            NA          UPPSEC    RURAL       Q3   420
# 171   FEMALE            NA          UPPSEC    RURAL       Q4   420
# 172   FEMALE            NA          UPPSEC    RURAL       Q5   420
# 173   FEMALE            NA          UPPSEC    RURAL       _T   863
# 174   FEMALE            NA          UPPSEC    URBAN       Q1   443
# 175   FEMALE            NA          UPPSEC    URBAN       Q2   443
# 176   FEMALE            NA          UPPSEC    URBAN       Q3   443
# 177   FEMALE            NA          UPPSEC    URBAN       Q4   443
# 178   FEMALE            NA          UPPSEC    URBAN       Q5   443
# 179   FEMALE            NA          UPPSEC    URBAN       _T   909
# 180   FEMALE          NUME              NA       NA       NA    35
# 181   FEMALE          PCPR              NA       NA       NA   238
# 182   FEMALE    SKILL_MATH          GRAD23       NA       NA   150
# 183   FEMALE    SKILL_MATH          LOWSEC       NA       NA   405
# 184   FEMALE    SKILL_MATH          PRIMAR       NA       NA   104
# 185   FEMALE    SKILL_READ          GRAD23       NA       NA   166
# 186   FEMALE    SKILL_READ          LOWSEC       NA       NA   381
# 187   FEMALE    SKILL_READ          PRIMAR       NA       NA    90
# 188   FEMALE          SOFT              NA       NA       NA   193
# 189   FEMALE          TRAF              NA       NA       NA   245
# 190     MALE          ARSP              NA       NA       NA   221
# 191     MALE          CMFL              NA       NA       NA   206
# 192     MALE          COPA              NA       NA       NA   190
# 193     MALE         EMAIL              NA       NA       NA   107
# 194     MALE          EPRS              NA       NA       NA   241
# 195     MALE          INST              NA       NA       NA   141
# 196     MALE          LITE              NA       NA       NA    37
# 197     MALE            NA          LOWSEC  ALLAREA       Q1   438
# 198     MALE            NA          LOWSEC  ALLAREA       Q2   438
# 199     MALE            NA          LOWSEC  ALLAREA       Q3   438
# 200     MALE            NA          LOWSEC  ALLAREA       Q4   438
# 201     MALE            NA          LOWSEC  ALLAREA       Q5   438
# 202     MALE            NA          LOWSEC  ALLAREA       _T  1136
# 203     MALE            NA          LOWSEC       NA       NA   699
# 204     MALE            NA          LOWSEC       NA       Q1   423
# 205     MALE            NA          LOWSEC       NA       Q2   423
# 206     MALE            NA          LOWSEC       NA       Q3   423
# 207     MALE            NA          LOWSEC       NA       Q4   423
# 208     MALE            NA          LOWSEC       NA       Q5   423
# 209     MALE            NA          LOWSEC       NA       _T   446
# 210     MALE            NA          LOWSEC    RURAL       Q1   423
# 211     MALE            NA          LOWSEC    RURAL       Q2   423
# 212     MALE            NA          LOWSEC    RURAL       Q3   423
# 213     MALE            NA          LOWSEC    RURAL       Q4   423
# 214     MALE            NA          LOWSEC    RURAL       Q5   423
# 215     MALE            NA          LOWSEC    RURAL       _T   869
# 216     MALE            NA          LOWSEC    URBAN       Q1   446
# 217     MALE            NA          LOWSEC    URBAN       Q2   446
# 218     MALE            NA          LOWSEC    URBAN       Q3   446
# 219     MALE            NA          LOWSEC    URBAN       Q4   446
# 220     MALE            NA          LOWSEC    URBAN       Q5   446
# 221     MALE            NA          LOWSEC    URBAN       _T   915
# 222     MALE            NA              NA       NA       NA  2351
# 223     MALE            NA          PREPRI       NA       NA   945
# 224     MALE            NA          PRIMAR  ALLAREA       Q1   438
# 225     MALE            NA          PRIMAR  ALLAREA       Q2   438
# 226     MALE            NA          PRIMAR  ALLAREA       Q3   438
# 227     MALE            NA          PRIMAR  ALLAREA       Q4   438
# 228     MALE            NA          PRIMAR  ALLAREA       Q5   438
# 229     MALE            NA          PRIMAR  ALLAREA       _T  1014
# 230     MALE            NA          PRIMAR       NA       NA  1304
# 231     MALE            NA          PRIMAR       NA       Q1   423
# 232     MALE            NA          PRIMAR       NA       Q2   423
# 233     MALE            NA          PRIMAR       NA       Q3   423
# 234     MALE            NA          PRIMAR       NA       Q4   423
# 235     MALE            NA          PRIMAR       NA       Q5   423
# 236     MALE            NA          PRIMAR       NA       _T   446
# 237     MALE            NA          PRIMAR    RURAL       Q1   423
# 238     MALE            NA          PRIMAR    RURAL       Q2   423
# 239     MALE            NA          PRIMAR    RURAL       Q3   423
# 240     MALE            NA          PRIMAR    RURAL       Q4   423
# 241     MALE            NA          PRIMAR    RURAL       Q5   423
# 242     MALE            NA          PRIMAR    RURAL       _T   869
# 243     MALE            NA          PRIMAR    URBAN       Q1   446
# 244     MALE            NA          PRIMAR    URBAN       Q2   446
# 245     MALE            NA          PRIMAR    URBAN       Q3   446
# 246     MALE            NA          PRIMAR    URBAN       Q4   446
# 247     MALE            NA          PRIMAR    URBAN       Q5   446
# 248     MALE            NA          PRIMAR    URBAN       _T   915
# 249     MALE            NA          SECOND       NA       NA   833
# 250     MALE            NA          UPPSEC  ALLAREA       Q1   435
# 251     MALE            NA          UPPSEC  ALLAREA       Q2   435
# 252     MALE            NA          UPPSEC  ALLAREA       Q3   435
# 253     MALE            NA          UPPSEC  ALLAREA       Q4   435
# 254     MALE            NA          UPPSEC  ALLAREA       Q5   435
# 255     MALE            NA          UPPSEC  ALLAREA       _T  1130
# 256     MALE            NA          UPPSEC       NA       NA   583
# 257     MALE            NA          UPPSEC       NA       Q1   420
# 258     MALE            NA          UPPSEC       NA       Q2   420
# 259     MALE            NA          UPPSEC       NA       Q3   420
# 260     MALE            NA          UPPSEC       NA       Q4   420
# 261     MALE            NA          UPPSEC       NA       Q5   420
# 262     MALE            NA          UPPSEC       NA       _T   443
# 263     MALE            NA          UPPSEC    RURAL       Q1   420
# 264     MALE            NA          UPPSEC    RURAL       Q2   420
# 265     MALE            NA          UPPSEC    RURAL       Q3   420
# 266     MALE            NA          UPPSEC    RURAL       Q4   420
# 267     MALE            NA          UPPSEC    RURAL       Q5   420
# 268     MALE            NA          UPPSEC    RURAL       _T   863
# 269     MALE            NA          UPPSEC    URBAN       Q1   443
# 270     MALE            NA          UPPSEC    URBAN       Q2   443
# 271     MALE            NA          UPPSEC    URBAN       Q3   443
# 272     MALE            NA          UPPSEC    URBAN       Q4   443
# 273     MALE            NA          UPPSEC    URBAN       Q5   443
# 274     MALE            NA          UPPSEC    URBAN       _T   909
# 275     MALE          NUME              NA       NA       NA    35
# 276     MALE          PCPR              NA       NA       NA   234
# 277     MALE    SKILL_MATH          GRAD23       NA       NA   150
# 278     MALE    SKILL_MATH          LOWSEC       NA       NA   405
# 279     MALE    SKILL_MATH          PRIMAR       NA       NA   104
# 280     MALE    SKILL_READ          GRAD23       NA       NA   166
# 281     MALE    SKILL_READ          LOWSEC       NA       NA   381
# 282     MALE    SKILL_READ          PRIMAR       NA       NA    90
# 283     MALE          SOFT              NA       NA       NA   188
# 284     MALE          TRAF              NA       NA       NA   240
# 285       NA          ARSP              NA       NA       NA    35
# 286       NA          CMFL              NA       NA       NA    37
# 287       NA          COPA              NA       NA       NA    35
# 288       NA         EMAIL              NA       NA       NA     6
# 289       NA          EPRS              NA       NA       NA    37
# 290       NA          INST              NA       NA       NA     7
# 291       NA          LITE              NA       NA       NA    28
# 292       NA          LITE              _T       NA       NA    82
# 293       NA            NA          LOWSEC  ALLAREA       Q1   438
# 294       NA            NA          LOWSEC  ALLAREA       Q2   438
# 295       NA            NA          LOWSEC  ALLAREA       Q3   438
# 296       NA            NA          LOWSEC  ALLAREA       Q4   438
# 297       NA            NA          LOWSEC  ALLAREA       Q5   438
# 298       NA            NA          LOWSEC  ALLAREA       _T   698
# 299       NA            NA          LOWSEC       NA       NA  4266
# 300       NA            NA          LOWSEC    RURAL       Q1   423
# 301       NA            NA          LOWSEC    RURAL       Q2   423
# 302       NA            NA          LOWSEC    RURAL       Q3   423
# 303       NA            NA          LOWSEC    RURAL       Q4   423
# 304       NA            NA          LOWSEC    RURAL       Q5   423
# 305       NA            NA          LOWSEC    RURAL       _T   446
# 306       NA            NA          LOWSEC    URBAN       Q1   446
# 307       NA            NA          LOWSEC    URBAN       Q2   446
# 308       NA            NA          LOWSEC    URBAN       Q3   446
# 309       NA            NA          LOWSEC    URBAN       Q4   446
# 310       NA            NA          LOWSEC    URBAN       Q5   446
# 311       NA            NA          LOWSEC    URBAN       _T   469
# 312       NA            NA              NA       NA       NA  4260
# 313       NA            NA          PREPRI       NA       NA   715
# 314       NA            NA          PRIMAR  ALLAREA       Q1   438
# 315       NA            NA          PRIMAR  ALLAREA       Q2   438
# 316       NA            NA          PRIMAR  ALLAREA       Q3   438
# 317       NA            NA          PRIMAR  ALLAREA       Q4   438
# 318       NA            NA          PRIMAR  ALLAREA       Q5   438
# 319       NA            NA          PRIMAR  ALLAREA       _T   576
# 320       NA            NA          PRIMAR       NA       NA  4804
# 321       NA            NA          PRIMAR    RURAL       Q1   423
# 322       NA            NA          PRIMAR    RURAL       Q2   423
# 323       NA            NA          PRIMAR    RURAL       Q3   423
# 324       NA            NA          PRIMAR    RURAL       Q4   423
# 325       NA            NA          PRIMAR    RURAL       Q5   423
# 326       NA            NA          PRIMAR    RURAL       _T   446
# 327       NA            NA          PRIMAR    URBAN       Q1   446
# 328       NA            NA          PRIMAR    URBAN       Q2   446
# 329       NA            NA          PRIMAR    URBAN       Q3   446
# 330       NA            NA          PRIMAR    URBAN       Q4   446
# 331       NA            NA          PRIMAR    URBAN       Q5   446
# 332       NA            NA          PRIMAR    URBAN       _T   469
# 333       NA            NA          SECOND       NA       NA   813
# 334       NA            NA          UPPSEC  ALLAREA       Q1   435
# 335       NA            NA          UPPSEC  ALLAREA       Q2   435
# 336       NA            NA          UPPSEC  ALLAREA       Q3   435
# 337       NA            NA          UPPSEC  ALLAREA       Q4   435
# 338       NA            NA          UPPSEC  ALLAREA       Q5   435
# 339       NA            NA          UPPSEC  ALLAREA       _T   695
# 340       NA            NA          UPPSEC       NA       NA  3994
# 341       NA            NA          UPPSEC    RURAL       Q1   420
# 342       NA            NA          UPPSEC    RURAL       Q2   420
# 343       NA            NA          UPPSEC    RURAL       Q3   420
# 344       NA            NA          UPPSEC    RURAL       Q4   420
# 345       NA            NA          UPPSEC    RURAL       Q5   420
# 346       NA            NA          UPPSEC    RURAL       _T   443
# 347       NA            NA          UPPSEC    URBAN       Q1   443
# 348       NA            NA          UPPSEC    URBAN       Q2   443
# 349       NA            NA          UPPSEC    URBAN       Q3   443
# 350       NA            NA          UPPSEC    URBAN       Q4   443
# 351       NA            NA          UPPSEC    URBAN       Q5   443
# 352       NA            NA          UPPSEC    URBAN       _T   466
# 353       NA          NUME              NA       NA       NA    28
# 354       NA          NUME              _T       NA       NA    66
# 355       NA          PCPR              NA       NA       NA    35
# 356       NA    SKILL_MATH          GRAD23       NA       NA   516
# 357       NA    SKILL_MATH          LOWSEC       NA       NA  1818
# 358       NA    SKILL_MATH          PRIMAR       NA       NA   347
# 359       NA    SKILL_READ          GRAD23       NA       NA   532
# 360       NA    SKILL_READ          LOWSEC       NA       NA  1747
# 361       NA    SKILL_READ          PRIMAR       NA       NA   284
# 362       NA          SOFT              NA       NA       NA    34
# 363       NA          TRAF              NA       NA       NA    35

# %%
feat_mat.shape
# Out:
# (364, 6)

# %%
feat_mat.columns
# Out:
# Index(['Sex', 'Type of skill', 'Education level', 'Location', 'Quantile',
#        'Freq'],
#       dtype='object')

# %%
feat_name_list_full = []

# sex, typeOfSkill, educationLevel, location, quantile
for s in feat_mat['Sex'].unique():
  for t in feat_mat['Type of skill'].unique():
    for e in feat_mat['Education level'].unique():
      for l in feat_mat['Location'].unique():
        for q in feat_mat['Quantile'].unique():
          feat_name = s+"."+t+"."+e+"."+l+"."+q
          feat_name_list.append(feat_name)
feat_name_list_full = list(set(feat_name_list))

# %%
feat_name_list
# Out:
# ['MALE.EPRS.GRAD23.ALLAREA.NA',
#  'MALE.EPRS._T.URBAN._T',
#  'BOTHSEX.NA.PREPRI.NA.Q3',
#  'MALE.CMFL.GRAD23.URBAN.Q1',
#  'NA.LITE.PRIMAR.NA.Q3',
#  'FEMALE.INST.GRAD23.ALLAREA._T',
#  'BOTHSEX.COPA.GRAD23.RURAL.Q2',
#  'MALE.COPA.PRIMAR.URBAN.NA',
#  'MALE.SOFT.PRIMAR.URBAN.Q4',
#  'FEMALE.PCPR.LOWSEC.NA.Q2',
#  'NA.COPA.UPPSEC.NA.Q1',
#  'MALE.NUME.GRAD23.ALLAREA.Q2',
#  'MALE.INST.LOWSEC.NA.Q4',
#  'BOTHSEX.COPA.PRIMAR.NA._T',
#  'MALE.LITE.LOWSEC.ALLAREA.Q4',
#  'FEMALE.EPRS.PREPRI.URBAN.Q5',
#  'MALE.SKILL_READ._T.NA.Q4',
#  'MALE.COPA.UPPSEC.RURAL.NA',
#  'BOTHSEX.INST.SECOND.NA.Q3',
#  'BOTHSEX.NA.NA.NA.Q2',
#  'BOTHSEX.LITE.PREPRI.NA.NA',
#  'FEMALE.COPA.NA.URBAN.Q3',
#  'FEMALE.NA.SECOND.NA.Q5',
#  'MALE.LITE._T.ALLAREA.Q4',
#  'FEMALE.SOFT.GRAD23.NA.Q5',
#  'BOTHSEX.CMFL._T.ALLAREA._T',
#  'FEMALE.SOFT.SECOND.NA.Q5',
#  'MALE.LITE._T.URBAN.Q5',
#  'NA.CMFL.LOWSEC.ALLAREA.Q2',
#  'FEMALE.SKILL_READ.PRIMAR.ALLAREA.Q4',
#  'NA.COPA.SECOND.NA.Q3',
#  'NA.PCPR.UPPSEC.NA.Q3',
#  'BOTHSEX.NA.NA.ALLAREA.Q3',
#  'NA.ARSP.SECOND.ALLAREA.Q1',
#  'NA.ARSP._T.NA.NA',
#  'NA.NUME.PREPRI.ALLAREA.Q1',
#  'NA.SOFT.UPPSEC.ALLAREA.Q1',
#  'NA.CMFL.PREPRI.RURAL.Q3',
#  'FEMALE.NUME.NA.URBAN.Q3',
#  'BOTHSEX.TRAF.GRAD23.RURAL.Q1',
#  'FEMALE.ARSP.NA.URBAN.Q4',
#  'FEMALE.SKILL_MATH._T.URBAN.Q1',
#  'MALE.LITE.PRIMAR.ALLAREA._T',
#  'NA.CMFL.PREPRI.ALLAREA.Q3',
#  'NA.NUME._T.RURAL.Q4',
#  'FEMALE.SKILL_READ.PREPRI.ALLAREA.NA',
#  'NA.SOFT.GRAD23.ALLAREA.Q4',
#  'NA.ARSP.PRIMAR.RURAL.Q2',
#  'MALE.NUME.PREPRI.RURAL._T',
#  'NA.SKILL_MATH.PRIMAR.URBAN.Q2',
#  'BOTHSEX.PCPR.PREPRI.NA.Q5',
#  'NA.CMFL.PRIMAR.URBAN.Q3',
#  'MALE.NUME.SECOND.NA.Q3',
#  'MALE.CMFL.GRAD23.ALLAREA.NA',
#  'BOTHSEX.PCPR._T.ALLAREA.Q3',
#  'NA.COPA._T.ALLAREA.Q5',
#  'MALE.EMAIL.SECOND.URBAN.Q4',
#  'BOTHSEX.SOFT.PREPRI.URBAN.Q3',
#  'NA.CMFL.PREPRI.RURAL.NA',
#  'FEMALE.COPA.UPPSEC.RURAL.Q3',
#  'MALE.COPA.PRIMAR.RURAL.Q5',
#  'MALE.NUME.NA.NA.Q2',
#  'BOTHSEX.EMAIL.GRAD23.RURAL._T',
#  'FEMALE.CMFL.PREPRI.NA.NA',
#  'NA.EPRS.PRIMAR.URBAN.Q2',
#  'MALE.LITE.SECOND.ALLAREA.Q4',
#  'MALE.SOFT.PREPRI.RURAL._T',
#  'NA.SOFT.NA.RURAL.Q2',
#  'FEMALE.EPRS.PREPRI.ALLAREA.Q2',
#  'MALE.SKILL_READ.PRIMAR.NA.Q1',
#  'NA.EPRS.LOWSEC.RURAL.Q5',
#  'NA.ARSP.NA.NA.Q3',
#  'NA.EMAIL.LOWSEC.URBAN.Q5',
#  'BOTHSEX.NA.GRAD23.URBAN.NA',
#  'FEMALE.SOFT.PREPRI.URBAN._T',
#  'NA.SKILL_READ.SECOND.RURAL._T',
#  'NA.COPA.PREPRI.ALLAREA.Q5',
#  'MALE.NUME.LOWSEC.RURAL.Q3',
#  'BOTHSEX.INST.LOWSEC.RURAL.Q5',
#  'FEMALE.LITE._T.NA.Q5',
#  'NA.LITE.LOWSEC.ALLAREA.Q4',
#  'FEMALE.PCPR.PREPRI.RURAL.Q2',
#  'FEMALE.CMFL.UPPSEC.RURAL.Q2',
#  'BOTHSEX.LITE.GRAD23.ALLAREA.Q5',
#  'NA.EMAIL.GRAD23.ALLAREA.NA',
#  'NA.LITE._T.RURAL.Q4',
#  'MALE.ARSP.NA.URBAN._T',
#  'FEMALE.SKILL_MATH._T.URBAN.Q4',
#  'BOTHSEX.CMFL.UPPSEC.NA.Q1',
#  'FEMALE.LITE.PREPRI.NA._T',
#  'MALE.COPA.LOWSEC.URBAN.Q4',
#  'BOTHSEX.SKILL_READ.SECOND.URBAN.Q4',
#  'NA.EPRS.NA.NA.Q5',
#  'NA.SKILL_READ.GRAD23.URBAN.Q1',
#  'NA.SOFT.SECOND.URBAN.NA',
#  'BOTHSEX.LITE.NA.NA.Q1',
#  'NA.SKILL_MATH.GRAD23.URBAN.NA',
#  'NA.LITE._T.NA.Q1',
#  'NA.SKILL_READ.UPPSEC.URBAN.Q4',
#  'MALE.EMAIL.NA.NA.Q3',
#  'FEMALE.LITE.GRAD23.URBAN.Q1',
#  'BOTHSEX.PCPR.PREPRI.ALLAREA.Q4',
#  'BOTHSEX.SOFT.GRAD23.NA.NA',
#  'MALE.EPRS.UPPSEC.RURAL.Q1',
#  'FEMALE.COPA.GRAD23.NA._T',
#  'FEMALE.ARSP.PREPRI.RURAL.Q2',
#  'MALE.NA.PRIMAR.ALLAREA._T',
#  'BOTHSEX.EPRS.UPPSEC.RURAL.Q5',
#  'MALE.SKILL_READ.NA.RURAL.Q3',
#  'FEMALE.EMAIL.LOWSEC.RURAL.Q1',
#  'NA.TRAF.SECOND.RURAL.Q2',
#  'FEMALE.ARSP.PRIMAR.RURAL.NA',
#  'MALE.COPA._T.RURAL.NA',
#  'MALE.LITE.SECOND.ALLAREA.Q5',
#  'NA.ARSP._T.ALLAREA.Q1',
#  'NA.CMFL.SECOND.ALLAREA.Q3',
#  'FEMALE.INST.PREPRI.ALLAREA._T',
#  'MALE.NUME.UPPSEC.NA.Q3',
#  'FEMALE.SKILL_READ.LOWSEC.URBAN._T',
#  'MALE.ARSP.LOWSEC.ALLAREA.Q2',
#  'NA.EMAIL._T.RURAL.Q5',
#  'NA.SKILL_READ._T.NA.Q2',
#  'MALE.NUME.PREPRI.NA.Q2',
#  'FEMALE.LITE._T.URBAN.NA',
#  'BOTHSEX.COPA.LOWSEC.URBAN.NA',
#  'MALE.SKILL_READ.GRAD23.RURAL.Q3',
#  'NA.ARSP.UPPSEC.RURAL.Q1',
#  'BOTHSEX.SOFT.UPPSEC.RURAL.Q3',
#  'MALE.INST.UPPSEC.RURAL.NA',
#  'BOTHSEX.TRAF.UPPSEC.RURAL.Q1',
#  'BOTHSEX.SOFT.PRIMAR.ALLAREA._T',
#  'FEMALE.LITE.PRIMAR.RURAL.Q3',
#  'FEMALE.TRAF.LOWSEC.NA.Q2',
#  'FEMALE.SKILL_MATH.PREPRI.URBAN._T',
#  'FEMALE.NA.LOWSEC.URBAN.Q4',
#  'BOTHSEX.EMAIL.GRAD23.RURAL.Q1',
#  'NA.COPA.GRAD23.ALLAREA._T',
#  'MALE.EMAIL._T.ALLAREA._T',
#  'FEMALE.INST.PREPRI.NA.Q1',
#  'BOTHSEX.LITE.PREPRI.RURAL._T',
#  'NA.SKILL_READ.UPPSEC.NA._T',
#  'NA.COPA.LOWSEC.ALLAREA.NA',
#  'BOTHSEX.PCPR.LOWSEC.RURAL._T',
#  'BOTHSEX.PCPR.UPPSEC.URBAN.Q2',
#  'FEMALE.CMFL._T.URBAN._T',
#  'MALE.NA.PREPRI.NA._T',
#  'FEMALE.PCPR.LOWSEC.RURAL._T',
#  'NA.EPRS.GRAD23.NA.Q3',
#  'NA.LITE._T.URBAN.Q1',
#  'NA.INST.PREPRI.ALLAREA.Q5',
#  'FEMALE.SKILL_READ.LOWSEC.ALLAREA.Q3',
#  'MALE.COPA.PRIMAR.RURAL.NA',
#  'MALE.NA._T.ALLAREA._T',
#  'MALE.TRAF.UPPSEC.NA.NA',
#  'NA.EPRS._T.URBAN.Q2',
#  'BOTHSEX.EPRS.PRIMAR.URBAN.Q2',
#  'MALE.NUME.SECOND.URBAN.Q2',
#  'FEMALE.SOFT.LOWSEC.RURAL.Q1',
#  'NA.NUME.PRIMAR.RURAL.Q5',
#  'NA.SKILL_READ.SECOND.URBAN.NA',
#  'NA.SKILL_READ._T.URBAN.Q4',
#  'BOTHSEX.COPA.GRAD23.NA.Q2',
#  'MALE.SKILL_READ._T.RURAL.Q5',
#  'BOTHSEX.SKILL_MATH.PRIMAR.ALLAREA.Q3',
#  'NA.ARSP.GRAD23.ALLAREA._T',
#  'BOTHSEX.INST.PRIMAR.NA.Q2',
#  'BOTHSEX.EPRS.SECOND.NA.Q1',
#  'BOTHSEX.NUME.UPPSEC.NA.Q4',
#  'BOTHSEX.COPA.LOWSEC.NA.NA',
#  'BOTHSEX.CMFL.PRIMAR.ALLAREA.Q1',
#  'MALE.CMFL._T.NA.Q3',
#  'NA.SOFT.PRIMAR.NA.Q3',
#  'BOTHSEX.COPA.GRAD23.URBAN.Q5',
#  'FEMALE.SKILL_READ.GRAD23.ALLAREA._T',
#  'MALE.INST._T.URBAN.Q5',
#  'FEMALE.EMAIL.UPPSEC.URBAN.Q5',
#  'MALE.COPA.GRAD23.ALLAREA.Q2',
#  'BOTHSEX.TRAF.SECOND.NA.Q1',
#  'FEMALE.SOFT.LOWSEC.URBAN.Q4',
#  'BOTHSEX.ARSP.NA.ALLAREA.Q3',
#  'BOTHSEX.EPRS.NA.URBAN.Q2',
#  'NA.EPRS._T.RURAL.Q3',
#  'MALE.NUME.UPPSEC.RURAL.Q2',
#  'NA.EPRS._T.URBAN.NA',
#  'BOTHSEX.EMAIL.GRAD23.RURAL.NA',
#  'MALE.COPA.PREPRI.ALLAREA.Q3',
#  'MALE.NUME.SECOND.ALLAREA.NA',
#  'BOTHSEX.SKILL_READ.GRAD23.NA.Q4',
#  'FEMALE.LITE.GRAD23.URBAN._T',
#  'FEMALE.SOFT.PREPRI.NA._T',
#  'FEMALE.SKILL_READ.LOWSEC.RURAL.Q4',
#  'MALE.EMAIL.LOWSEC.RURAL.Q4',
#  'MALE.EMAIL.UPPSEC.NA.Q1',
#  'MALE.INST.UPPSEC.NA.Q4',
#  'MALE.LITE.SECOND.NA._T',
#  'MALE.COPA.SECOND.NA.Q4',
#  'MALE.SKILL_MATH.PREPRI.NA.Q4',
#  'NA.LITE.PRIMAR.RURAL.Q4',
#  'BOTHSEX.TRAF.PRIMAR.ALLAREA.Q5',
#  'FEMALE.INST._T.URBAN.NA',
#  'NA.CMFL.PRIMAR.RURAL.Q1',
#  'BOTHSEX.LITE.LOWSEC.ALLAREA.Q5',
#  'FEMALE.SKILL_READ.GRAD23.ALLAREA.Q4',
#  'BOTHSEX.NA.PREPRI.ALLAREA.Q1',
#  'NA.SOFT.SECOND.ALLAREA._T',
#  'FEMALE.SKILL_READ._T.NA.Q1',
#  'NA.ARSP._T.ALLAREA.Q4',
#  'FEMALE.COPA.UPPSEC.URBAN.Q2',
#  'NA.SOFT.SECOND.ALLAREA.Q1',
#  'BOTHSEX.SKILL_READ._T.URBAN.Q3',
#  'BOTHSEX.TRAF.PREPRI.RURAL.Q3',
#  'MALE.CMFL.UPPSEC.ALLAREA._T',
#  'MALE.INST.UPPSEC.RURAL.Q3',
#  'BOTHSEX.PCPR.LOWSEC.RURAL.Q2',
#  'FEMALE.INST.SECOND.NA.Q4',
#  'MALE.TRAF.NA.URBAN.Q1',
#  'FEMALE.CMFL.NA.ALLAREA._T',
#  'NA.SKILL_MATH.GRAD23.RURAL.Q5',
#  'FEMALE.SKILL_READ.PREPRI.URBAN.Q2',
#  'NA.SOFT.PRIMAR.URBAN.Q5',
#  'FEMALE.TRAF.GRAD23.NA._T',
#  'MALE.SKILL_MATH._T.NA.Q2',
#  'MALE.NUME._T.NA.Q1',
#  'FEMALE.SOFT.LOWSEC.URBAN.Q3',
#  'FEMALE.COPA._T.ALLAREA.Q3',
#  'BOTHSEX.NUME.LOWSEC.URBAN.Q3',
#  'FEMALE.SKILL_MATH.LOWSEC.ALLAREA.Q3',
#  'NA.SOFT.SECOND.RURAL.Q4',
#  'MALE.TRAF.LOWSEC.ALLAREA.Q3',
#  'BOTHSEX.EMAIL.SECOND.RURAL.NA',
#  'NA.ARSP.PRIMAR.ALLAREA.Q5',
#  'NA.TRAF.NA.URBAN.NA',
#  'MALE.NUME.NA.RURAL._T',
#  'MALE.PCPR.GRAD23.RURAL.Q1',
#  'NA.SKILL_MATH.PREPRI.RURAL.Q1',
#  'BOTHSEX.SOFT.UPPSEC.NA.Q1',
#  'BOTHSEX.LITE.UPPSEC.URBAN.Q5',
#  'MALE.COPA.GRAD23.ALLAREA.NA',
#  'MALE.EMAIL.NA.RURAL.Q2',
#  'MALE.SKILL_MATH.LOWSEC.URBAN.Q2',
#  'FEMALE.PCPR.NA.RURAL.Q4',
#  'FEMALE.EPRS.PRIMAR.ALLAREA.Q4',
#  'FEMALE.EPRS.SECOND.ALLAREA.Q1',
#  'BOTHSEX.CMFL.PRIMAR.NA.Q3',
#  'BOTHSEX.SOFT.UPPSEC.ALLAREA.Q3',
#  'FEMALE.LITE.UPPSEC.RURAL.NA',
#  'NA.CMFL.UPPSEC.RURAL.Q1',
#  'FEMALE.EMAIL.LOWSEC.RURAL.NA',
#  'NA.LITE.PRIMAR.ALLAREA.NA',
#  'NA.TRAF.NA.URBAN.Q1',
#  'FEMALE.SKILL_READ._T.RURAL.Q2',
#  'BOTHSEX.TRAF.UPPSEC.URBAN.Q3',
#  'NA.TRAF._T.RURAL.Q2',
#  'BOTHSEX.SKILL_MATH.GRAD23.ALLAREA.Q3',
#  'MALE.SOFT.LOWSEC.RURAL.Q1',
#  'MALE.CMFL.PREPRI.URBAN.NA',
#  'NA.SKILL_READ._T.ALLAREA.Q2',
#  'NA.NUME._T.URBAN.Q5',
#  'BOTHSEX.EMAIL.PREPRI.NA.NA',
#  'BOTHSEX.EMAIL.PREPRI.NA.Q4',
#  'FEMALE.SKILL_READ.PRIMAR.NA.NA',
#  'FEMALE.NA.LOWSEC.URBAN._T',
#  'MALE.EMAIL.UPPSEC.RURAL.Q4',
#  'NA.PCPR.GRAD23.URBAN.Q1',
#  'NA.SKILL_READ.PRIMAR.NA.Q5',
#  'BOTHSEX.SOFT.UPPSEC.URBAN.Q4',
#  'FEMALE.NUME.NA.NA.Q5',
#  'MALE.COPA.LOWSEC.RURAL.NA',
#  'FEMALE.EMAIL.PRIMAR.URBAN.Q5',
#  'MALE.INST.LOWSEC.RURAL.Q3',
#  'MALE.SKILL_READ.UPPSEC.ALLAREA._T',
#  'FEMALE.SOFT.GRAD23.NA.NA',
#  'BOTHSEX.EMAIL.UPPSEC.ALLAREA.Q4',
#  'FEMALE.SKILL_READ._T.NA.Q2',
#  'BOTHSEX.NA.NA.NA.Q5',
#  'FEMALE.PCPR.LOWSEC.ALLAREA.Q5',
#  'MALE.SKILL_READ.SECOND.URBAN.NA',
#  'MALE.LITE.PREPRI.URBAN.Q4',
#  'MALE.SKILL_READ.NA.ALLAREA.Q1',
#  'BOTHSEX.CMFL.PREPRI.URBAN.Q4',
#  'NA.EPRS.LOWSEC.URBAN.Q2',
#  'FEMALE.INST.PREPRI.ALLAREA.Q4',
#  'MALE.SKILL_READ.PREPRI.RURAL.NA',
#  'MALE.SKILL_READ.NA.URBAN.Q2',
#  'BOTHSEX.CMFL.PRIMAR.RURAL.Q4',
#  'BOTHSEX.ARSP.SECOND.URBAN.Q3',
#  'FEMALE.INST.LOWSEC.RURAL.Q3',
#  'FEMALE.ARSP.UPPSEC.URBAN.Q3',
#  'NA.NUME.SECOND.NA.Q5',
#  'MALE.LITE.UPPSEC.NA.Q5',
#  'BOTHSEX.COPA.PRIMAR.URBAN._T',
#  'BOTHSEX.EMAIL.UPPSEC.ALLAREA.Q5',
#  'BOTHSEX.EPRS.NA.NA.Q2',
#  'BOTHSEX.EPRS.PRIMAR.URBAN.Q4',
#  'FEMALE.SKILL_MATH.LOWSEC.RURAL.Q5',
#  'FEMALE.COPA._T.URBAN.Q1',
#  'MALE.INST.GRAD23.ALLAREA.Q2',
#  'NA.ARSP.PREPRI.RURAL.Q3',
#  'NA.COPA.LOWSEC.NA.Q4',
#  'BOTHSEX.TRAF.PRIMAR.RURAL.Q5',
#  'BOTHSEX.SKILL_MATH.PREPRI.URBAN.Q2',
#  'BOTHSEX.COPA.NA.ALLAREA.Q1',
#  'NA.SKILL_MATH.NA.RURAL.Q5',
#  'FEMALE.NA.NA.NA.NA',
#  'BOTHSEX.SKILL_READ._T.RURAL.NA',
#  'NA.SKILL_READ.PRIMAR.RURAL.Q1',
#  'BOTHSEX.COPA.PREPRI.URBAN.Q4',
#  'BOTHSEX.NA.NA.NA.NA',
#  'BOTHSEX.PCPR.PREPRI.NA.Q2',
#  'BOTHSEX.SKILL_READ.PRIMAR.NA.Q2',
#  'FEMALE.NA.NA.RURAL.Q4',
#  'FEMALE.SKILL_MATH.GRAD23.NA.Q2',
#  'BOTHSEX.TRAF.NA.NA.Q1',
#  'FEMALE.NA.LOWSEC.ALLAREA.Q2',
#  'BOTHSEX.PCPR.UPPSEC.URBAN._T',
#  'FEMALE.EPRS.NA.ALLAREA.Q2',
#  'MALE.SKILL_MATH._T.RURAL.Q5',
#  'BOTHSEX.INST._T.ALLAREA.Q5',
#  'FEMALE.COPA.GRAD23.NA.Q4',
#  'NA.CMFL.PRIMAR.ALLAREA.Q3',
#  'NA.LITE.GRAD23.URBAN.Q1',
#  'MALE.CMFL.UPPSEC.ALLAREA.Q1',
#  'FEMALE.SOFT.PREPRI.ALLAREA.Q4',
#  'FEMALE.NA.LOWSEC.URBAN.NA',
#  'FEMALE.NA.GRAD23.NA.NA',
#  'NA.ARSP._T.RURAL.Q3',
#  'NA.LITE.NA.NA.Q2',
#  'MALE.CMFL.LOWSEC.ALLAREA.Q1',
#  'NA.LITE.PRIMAR.NA._T',
#  'FEMALE.EMAIL.NA.ALLAREA.Q2',
#  'NA.SKILL_MATH._T.ALLAREA.Q1',
#  'BOTHSEX.LITE.GRAD23.RURAL.Q5',
#  'MALE.SKILL_READ.UPPSEC.RURAL._T',
#  'FEMALE.SKILL_MATH.NA.URBAN._T',
#  'BOTHSEX.SKILL_MATH.UPPSEC.NA.NA',
#  'FEMALE.INST._T.URBAN.Q5',
#  'BOTHSEX.COPA.GRAD23.RURAL.Q5',
#  'MALE.CMFL.NA.NA.Q1',
#  'NA.NUME.UPPSEC.ALLAREA.Q5',
#  'FEMALE.LITE.PREPRI.ALLAREA.Q1',
#  'NA.LITE.PREPRI.ALLAREA.Q3',
#  'NA.EMAIL._T.RURAL.Q2',
#  'FEMALE.SOFT.PREPRI.NA.Q2',
#  'NA.TRAF.PRIMAR.URBAN.Q4',
#  'NA.TRAF.LOWSEC.NA.Q5',
#  'MALE.NA.SECOND.RURAL.Q4',
#  'MALE.COPA.PREPRI.URBAN._T',
#  'BOTHSEX.SKILL_READ.LOWSEC.RURAL.Q2',
#  'FEMALE.TRAF._T.RURAL.Q3',
#  'MALE.TRAF._T.NA.Q5',
#  'NA.ARSP.LOWSEC.RURAL.Q5',
#  'MALE.EMAIL.NA.ALLAREA.Q3',
#  'NA.COPA.PREPRI.RURAL.Q5',
#  'BOTHSEX.INST.PRIMAR.ALLAREA.Q4',
#  'NA.INST.SECOND.URBAN.Q1',
#  'NA.NUME.NA.NA._T',
#  'FEMALE.TRAF.UPPSEC.URBAN.Q5',
#  'NA.NA.UPPSEC.URBAN._T',
#  'FEMALE.EPRS.SECOND.RURAL.Q3',
#  'FEMALE.SOFT.PREPRI.NA.NA',
#  'FEMALE.SKILL_MATH.UPPSEC.ALLAREA.Q3',
#  'MALE.COPA._T.ALLAREA._T',
#  'BOTHSEX.LITE.SECOND.RURAL._T',
#  'FEMALE.ARSP.NA.URBAN.Q5',
#  'FEMALE.SOFT.SECOND.ALLAREA.Q2',
#  'BOTHSEX.PCPR.PREPRI.RURAL.NA',
#  'NA.SOFT.PRIMAR.URBAN.Q4',
#  'MALE.EMAIL.PRIMAR.ALLAREA.Q4',
#  'FEMALE.INST.PRIMAR.NA.NA',
#  'FEMALE.PCPR.LOWSEC.RURAL.Q4',
#  'NA.COPA.SECOND.URBAN.Q4',
#  'MALE.SKILL_READ.SECOND.NA.Q2',
#  'NA.NA.PRIMAR.ALLAREA.Q4',
#  'BOTHSEX.EMAIL._T.RURAL.Q1',
#  'BOTHSEX.COPA.SECOND.URBAN.Q5',
#  'FEMALE.LITE.PREPRI.URBAN._T',
#  'BOTHSEX.PCPR.GRAD23.URBAN.Q5',
#  'MALE.SOFT.LOWSEC.RURAL.Q3',
#  'FEMALE.PCPR.NA.ALLAREA.Q4',
#  'NA.COPA.GRAD23.URBAN.Q2',
#  'NA.TRAF.NA.RURAL.Q2',
#  'NA.EMAIL.NA.RURAL.NA',
#  'BOTHSEX.SOFT._T.URBAN.NA',
#  'MALE.CMFL.PREPRI.ALLAREA._T',
#  'FEMALE.COPA.GRAD23.ALLAREA._T',
#  'MALE.EMAIL.GRAD23.URBAN.Q2',
#  'NA.PCPR._T.URBAN._T',
#  'BOTHSEX.SKILL_READ.NA.ALLAREA.NA',
#  'FEMALE.INST.NA.RURAL.NA',
#  'BOTHSEX.COPA.PREPRI.RURAL._T',
#  'NA.SKILL_READ.GRAD23.RURAL.Q5',
#  'MALE.SKILL_MATH.GRAD23.ALLAREA._T',
#  'FEMALE.SOFT.NA.RURAL._T',
#  'MALE.COPA.PRIMAR.NA._T',
#  'BOTHSEX.INST.NA.ALLAREA.NA',
#  'BOTHSEX.EMAIL.LOWSEC.RURAL.Q5',
#  'NA.SKILL_MATH.SECOND.ALLAREA._T',
#  'NA.EMAIL.PRIMAR.URBAN.Q1',
#  'NA.SKILL_READ.GRAD23.ALLAREA.Q2',
#  'BOTHSEX.SKILL_READ.SECOND.URBAN.NA',
#  'FEMALE.NA.NA.URBAN.NA',
#  'BOTHSEX.COPA.SECOND.RURAL._T',
#  'FEMALE.EMAIL.NA.NA._T',
#  'MALE.SKILL_MATH.GRAD23.ALLAREA.Q4',
#  'MALE.NA.NA.NA.Q4',
#  'FEMALE.NA.PRIMAR.ALLAREA.Q2',
#  'FEMALE.COPA.GRAD23.ALLAREA.Q3',
#  'MALE.SKILL_READ.PREPRI.RURAL.Q5',
#  'FEMALE.PCPR.NA.ALLAREA.NA',
#  'FEMALE.TRAF.LOWSEC.NA.Q4',
#  'BOTHSEX.COPA.SECOND.RURAL.Q1',
#  'MALE.COPA._T.URBAN.Q3',
#  'FEMALE.NA.GRAD23.URBAN.NA',
#  'MALE.EPRS.NA.URBAN.Q4',
#  'MALE.PCPR.LOWSEC.NA._T',
#  'FEMALE.NUME.GRAD23.NA.Q4',
#  'FEMALE.SOFT.PREPRI.NA.Q5',
#  'BOTHSEX.PCPR.PREPRI.URBAN.NA',
#  'MALE.CMFL.SECOND.ALLAREA.Q4',
#  'BOTHSEX.ARSP.SECOND.NA.Q1',
#  'NA.PCPR.PREPRI.URBAN.Q4',
#  'BOTHSEX.SOFT.LOWSEC.URBAN._T',
#  'MALE.COPA.PREPRI.ALLAREA.Q2',
#  'NA.PCPR.GRAD23.NA.Q4',
#  'MALE.LITE.SECOND.RURAL.Q4',
#  'MALE.LITE.PRIMAR.URBAN.NA',
#  'MALE.INST.PRIMAR.ALLAREA._T',
#  'MALE.NA.LOWSEC.ALLAREA.Q5',
#  'NA.PCPR.NA.NA.Q1',
#  'MALE.NA.GRAD23.NA.Q2',
#  'MALE.EPRS.GRAD23.RURAL.Q1',
#  'MALE.CMFL.UPPSEC.NA.Q3',
#  'BOTHSEX.TRAF.NA.NA.Q4',
#  'NA.ARSP.NA.NA.Q4',
#  'FEMALE.INST.NA.RURAL.Q4',
#  'BOTHSEX.LITE.LOWSEC.ALLAREA.Q2',
#  'MALE.NA.SECOND.ALLAREA.Q4',
#  'NA.ARSP.SECOND.URBAN.Q5',
#  'NA.TRAF.LOWSEC.URBAN.Q2',
#  'NA.SKILL_READ.SECOND.RURAL.Q2',
#  'BOTHSEX.SKILL_READ.SECOND.RURAL.NA',
#  'MALE.NA.PRIMAR.URBAN.Q2',
#  'BOTHSEX.NA.GRAD23.URBAN._T',
#  'NA.CMFL.NA.ALLAREA.Q5',
#  'BOTHSEX.SKILL_READ.GRAD23.URBAN.Q3',
#  'FEMALE.ARSP.PRIMAR.URBAN.Q5',
#  'FEMALE.SKILL_MATH.GRAD23.ALLAREA.NA',
#  'FEMALE.ARSP._T.ALLAREA.Q2',
#  'BOTHSEX.PCPR.GRAD23.RURAL.Q5',
#  'MALE.COPA.UPPSEC.RURAL.Q4',
#  'MALE.COPA.LOWSEC.RURAL.Q3',
#  'FEMALE.EPRS.LOWSEC.NA.Q4',
#  'NA.LITE.SECOND.RURAL.Q5',
#  'NA.TRAF.PRIMAR.NA.Q5',
#  'BOTHSEX.CMFL.LOWSEC.NA.Q1',
#  'FEMALE.EMAIL.UPPSEC.ALLAREA.Q2',
#  'FEMALE.EMAIL._T.ALLAREA.Q2',
#  'BOTHSEX.EMAIL.UPPSEC.NA.Q4',
#  'NA.EPRS.GRAD23.NA.Q1',
#  'NA.SKILL_READ.PREPRI.RURAL.Q5',
#  'NA.TRAF.PRIMAR.ALLAREA.Q5',
#  'MALE.TRAF.GRAD23.URBAN.Q3',
#  'NA.CMFL._T.URBAN.Q3',
#  'FEMALE.INST.PRIMAR.NA.Q2',
#  'MALE.PCPR.LOWSEC.RURAL.Q2',
#  'NA.LITE.NA.RURAL.Q3',
#  'FEMALE.EPRS.GRAD23.NA.Q3',
#  'BOTHSEX.INST.UPPSEC.NA.Q2',
#  'MALE.NUME.NA.URBAN.Q2',
#  'BOTHSEX.LITE._T.NA.Q3',
#  'FEMALE.EMAIL.SECOND.ALLAREA.Q2',
#  'MALE.NA.GRAD23.RURAL.Q1',
#  'NA.EPRS.SECOND.RURAL.Q5',
#  'NA.NUME.GRAD23.URBAN.Q4',
#  'NA.SOFT.UPPSEC.ALLAREA.Q2',
#  'NA.EPRS.NA.NA.Q3',
#  'MALE.COPA._T.RURAL.Q5',
#  'FEMALE.SOFT._T.ALLAREA.Q5',
#  'FEMALE.EMAIL._T.URBAN.Q4',
#  'NA.SKILL_MATH.UPPSEC.ALLAREA.Q1',
#  'BOTHSEX.TRAF.LOWSEC.ALLAREA.Q3',
#  'MALE.SKILL_READ.NA.ALLAREA.NA',
#  'MALE.PCPR.GRAD23.URBAN.Q2',
#  'FEMALE.CMFL.UPPSEC.URBAN.NA',
#  'FEMALE.PCPR._T.ALLAREA.Q1',
#  'MALE.SKILL_MATH.SECOND.RURAL.Q4',
#  'MALE.LITE._T.URBAN.NA',
#  'NA.INST.PRIMAR.ALLAREA.Q1',
#  'BOTHSEX.INST._T.ALLAREA._T',
#  'FEMALE.EMAIL.PRIMAR.URBAN.Q3',
#  'NA.EPRS._T.NA.Q3',
#  'MALE.EPRS.LOWSEC.URBAN.Q3',
#  'MALE.ARSP._T.RURAL.Q2',
#  'NA.SKILL_READ.SECOND.RURAL.NA',
#  'MALE.EPRS._T.URBAN.Q3',
#  'BOTHSEX.ARSP.PRIMAR.ALLAREA.Q1',
#  'BOTHSEX.ARSP.PREPRI.ALLAREA._T',
#  'NA.NA.NA.NA.Q5',
#  'BOTHSEX.INST.UPPSEC.URBAN.Q2',
#  'BOTHSEX.NUME.NA.RURAL.Q1',
#  'NA.SKILL_MATH.LOWSEC.ALLAREA.Q3',
#  'BOTHSEX.SKILL_MATH.PRIMAR.ALLAREA._T',
#  'BOTHSEX.SOFT.PRIMAR.NA.Q5',
#  'FEMALE.CMFL.UPPSEC.URBAN.Q2',
#  'FEMALE.INST.PRIMAR.ALLAREA.Q1',
#  'BOTHSEX.CMFL._T.RURAL.Q3',
#  'NA.CMFL.UPPSEC.RURAL.NA',
#  'FEMALE.NUME.NA.NA.Q4',
#  'BOTHSEX.NUME.PREPRI.RURAL.Q5',
#  'NA.SKILL_READ.LOWSEC.NA.NA',
#  'BOTHSEX.ARSP.GRAD23.ALLAREA.Q5',
#  'BOTHSEX.COPA.SECOND.NA.Q4',
#  'BOTHSEX.LITE.UPPSEC.ALLAREA.Q3',
#  'MALE.NA.LOWSEC.NA.Q5',
#  'MALE.NUME.SECOND.NA.Q4',
#  'BOTHSEX.NA.GRAD23.URBAN.Q1',
#  'MALE.TRAF.PREPRI.URBAN.Q2',
#  'MALE.ARSP.SECOND.URBAN.Q5',
#  'FEMALE.EPRS.PRIMAR.RURAL.Q5',
#  'BOTHSEX.SOFT.PRIMAR.NA.Q3',
#  'NA.SKILL_READ.UPPSEC.URBAN.Q5',
#  'MALE.LITE.SECOND.NA.NA',
#  'FEMALE.PCPR.SECOND.NA._T',
#  'MALE.TRAF.GRAD23.URBAN.Q5',
#  'NA.SOFT.PREPRI.NA.NA',
#  'FEMALE.SOFT.UPPSEC.URBAN.Q1',
#  'MALE.CMFL.LOWSEC.URBAN.Q2',
#  'NA.NUME.NA.URBAN.Q3',
#  'NA.SOFT.PREPRI.NA.Q5',
#  'MALE.NUME.PRIMAR.URBAN.NA',
#  'NA.SOFT.NA.RURAL.NA',
#  'NA.NUME.PREPRI.URBAN.Q3',
#  'NA.LITE.PREPRI.RURAL.NA',
#  'BOTHSEX.NUME.LOWSEC.ALLAREA.Q4',
#  'MALE.INST.GRAD23.RURAL.NA',
#  'BOTHSEX.INST.SECOND.NA.Q1',
#  'MALE.EMAIL.UPPSEC.ALLAREA._T',
#  'MALE.SKILL_MATH.UPPSEC.ALLAREA.NA',
#  'MALE.SKILL_READ.UPPSEC.URBAN.Q5',
#  'BOTHSEX.SKILL_MATH.PRIMAR.ALLAREA.Q2',
#  'FEMALE.NA.SECOND.ALLAREA._T',
#  'FEMALE.PCPR.NA.URBAN.Q2',
#  'NA.NA.PREPRI.RURAL.NA',
#  'BOTHSEX.CMFL.UPPSEC.ALLAREA.Q1',
#  'BOTHSEX.LITE.UPPSEC.URBAN._T',
#  'FEMALE.SOFT.PRIMAR.ALLAREA.Q4',
#  'MALE.EMAIL.NA.URBAN.Q4',
#  'BOTHSEX.INST.PRIMAR.URBAN.Q2',
#  'NA.CMFL.PREPRI.ALLAREA._T',
#  'NA.TRAF.GRAD23.URBAN.Q1',
#  'MALE.TRAF.PREPRI.NA.Q2',
#  'BOTHSEX.TRAF.UPPSEC.ALLAREA.Q2',
#  'NA.INST.NA.NA.Q2',
#  'FEMALE.ARSP.PRIMAR.NA.Q4',
#  'FEMALE.COPA.NA.RURAL.Q4',
#  'BOTHSEX.LITE._T.RURAL.Q4',
#  'FEMALE.ARSP.NA.URBAN.Q2',
#  'NA.CMFL.NA.URBAN._T',
#  'FEMALE.NA._T.URBAN.Q5',
#  'MALE.ARSP.UPPSEC.NA.Q5',
#  'FEMALE.INST.LOWSEC.URBAN.Q1',
#  'MALE.ARSP._T.URBAN.Q3',
#  'MALE.CMFL.PRIMAR.RURAL.Q3',
#  'MALE.PCPR._T.URBAN.Q1',
#  'NA.CMFL.PREPRI.RURAL.Q1',
#  'NA.LITE.UPPSEC.ALLAREA.Q3',
#  'BOTHSEX.NA.PRIMAR.URBAN.NA',
#  'NA.INST.GRAD23.NA.Q2',
#  'NA.LITE._T.URBAN.Q5',
#  'BOTHSEX.ARSP.UPPSEC.URBAN.Q4',
#  'NA.LITE.UPPSEC.NA.Q4',
#  'BOTHSEX.PCPR.SECOND.RURAL.Q1',
#  'NA.SKILL_READ.LOWSEC.RURAL.Q2',
#  'FEMALE.INST.GRAD23.RURAL.Q4',
#  'NA.ARSP.PREPRI.ALLAREA.NA',
#  'MALE.TRAF.UPPSEC.NA._T',
#  'BOTHSEX.PCPR.GRAD23.URBAN.Q1',
#  'FEMALE.ARSP.PREPRI.URBAN.Q2',
#  'NA.EMAIL.PRIMAR.RURAL.Q2',
#  'MALE.COPA.UPPSEC.ALLAREA.NA',
#  'FEMALE.INST.SECOND.RURAL._T',
#  'NA.INST.PREPRI.RURAL.Q4',
#  'NA.PCPR.LOWSEC.URBAN.Q4',
#  'FEMALE.SKILL_READ.SECOND.URBAN.Q3',
#  'BOTHSEX.INST.UPPSEC.NA.Q1',
#  'FEMALE.NUME.GRAD23.ALLAREA._T',
#  'MALE.LITE.SECOND.URBAN._T',
#  'NA.SOFT.UPPSEC.NA.Q5',
#  'NA.TRAF.PRIMAR.NA.Q3',
#  'NA.EMAIL.LOWSEC.URBAN.Q1',
#  'FEMALE.SKILL_READ.GRAD23.URBAN.Q5',
#  'NA.PCPR.GRAD23.ALLAREA.Q4',
#  'FEMALE.ARSP.LOWSEC.URBAN._T',
#  'FEMALE.EPRS.NA.RURAL.Q4',
#  'MALE.EMAIL.NA.ALLAREA.NA',
#  'NA.TRAF.LOWSEC.RURAL.Q4',
#  'BOTHSEX.COPA._T.URBAN.Q3',
#  'NA.EMAIL.GRAD23.URBAN.Q2',
#  'FEMALE.TRAF.SECOND.URBAN._T',
#  'NA.SKILL_MATH.PRIMAR.NA.Q2',
#  'NA.SKILL_MATH.GRAD23.ALLAREA.Q4',
#  'MALE.ARSP.NA.RURAL.Q5',
#  'BOTHSEX.SKILL_READ.UPPSEC.RURAL.Q2',
#  'MALE.SKILL_READ.PREPRI.ALLAREA.NA',
#  'NA.PCPR.LOWSEC.NA._T',
#  'NA.SOFT.GRAD23.RURAL.Q3',
#  'MALE.ARSP.LOWSEC.ALLAREA._T',
#  'NA.LITE.NA.URBAN.Q1',
#  'BOTHSEX.TRAF.UPPSEC.NA.Q5',
#  'FEMALE.TRAF.GRAD23.ALLAREA._T',
#  'FEMALE.COPA.PREPRI.URBAN._T',
#  'BOTHSEX.NUME.NA.RURAL.Q5',
#  'BOTHSEX.PCPR.PRIMAR.URBAN.Q2',
#  'BOTHSEX.TRAF.LOWSEC.ALLAREA._T',
#  'NA.COPA._T.URBAN.NA',
#  'FEMALE.EPRS.PREPRI.URBAN.NA',
#  'NA.INST.PREPRI.URBAN.Q5',
#  'NA.INST.PRIMAR.URBAN.Q3',
#  'BOTHSEX.CMFL.PRIMAR.URBAN.Q4',
#  'MALE.SKILL_MATH.NA.URBAN.NA',
#  'NA.CMFL.LOWSEC.URBAN.Q3',
#  'BOTHSEX.NA.NA.NA.Q3',
#  'FEMALE.SOFT.GRAD23.RURAL.NA',
#  'NA.EPRS._T.URBAN.Q4',
#  'MALE.NA.LOWSEC.RURAL.Q2',
#  'NA.PCPR.PREPRI.RURAL.Q4',
#  'BOTHSEX.CMFL._T.NA.Q2',
#  'FEMALE.INST._T.NA.Q2',
#  'BOTHSEX.INST.LOWSEC.ALLAREA._T',
#  'FEMALE.SKILL_READ.SECOND.NA.Q4',
#  'MALE.CMFL.UPPSEC.NA.Q2',
#  'MALE.COPA.GRAD23.URBAN.Q3',
#  'MALE.NUME.PRIMAR.RURAL.Q1',
#  'FEMALE.TRAF.GRAD23.URBAN.Q4',
#  'NA.SKILL_MATH.NA.NA.Q5',
#  'BOTHSEX.SKILL_READ.LOWSEC.RURAL.Q4',
#  'NA.EMAIL.GRAD23.URBAN.Q4',
#  'FEMALE.EMAIL.PRIMAR.ALLAREA.Q1',
#  'FEMALE.EMAIL.GRAD23.RURAL.Q4',
#  'FEMALE.TRAF.LOWSEC.NA.NA',
#  'NA.ARSP.LOWSEC.ALLAREA.Q3',
#  'NA.TRAF.GRAD23.NA.Q5',
#  'NA.LITE.UPPSEC.RURAL.Q3',
#  'NA.EMAIL.PREPRI.RURAL.Q2',
#  'FEMALE.NUME.SECOND.RURAL.Q4',
#  'FEMALE.PCPR.SECOND.NA.Q2',
#  'NA.SKILL_READ.UPPSEC.NA.Q4',
#  'BOTHSEX.SOFT.LOWSEC.URBAN.Q1',
#  'NA.SOFT.UPPSEC.URBAN.Q3',
#  'FEMALE.ARSP._T.ALLAREA.Q4',
#  'FEMALE.SKILL_READ.UPPSEC.NA.Q5',
#  'BOTHSEX.ARSP.UPPSEC.ALLAREA._T',
#  'NA.LITE.UPPSEC.ALLAREA.NA',
#  'FEMALE.LITE.GRAD23.NA.Q2',
#  'BOTHSEX.INST.NA.RURAL.Q2',
#  'MALE.NUME._T.NA.NA',
#  'FEMALE.NA.GRAD23.RURAL.NA',
#  'MALE.SKILL_MATH.UPPSEC.RURAL.Q3',
#  'NA.CMFL.PREPRI.NA.NA',
#  'FEMALE.SKILL_READ.LOWSEC.RURAL.Q1',
#  'MALE.SKILL_READ.UPPSEC.ALLAREA.Q5',
#  'MALE.SKILL_MATH._T.RURAL.NA',
#  'FEMALE.LITE.GRAD23.NA.NA',
#  'BOTHSEX.SKILL_READ.NA.NA._T',
#  'MALE.NA._T.RURAL.Q3',
#  'NA.ARSP.GRAD23.NA.Q2',
#  'NA.PCPR.UPPSEC.RURAL.Q2',
#  'BOTHSEX.CMFL.UPPSEC.URBAN.Q5',
#  'MALE.NA.NA.RURAL.Q5',
#  'MALE.SKILL_READ.LOWSEC.URBAN.Q5',
#  'NA.NA.LOWSEC.URBAN.Q1',
#  'BOTHSEX.EMAIL.LOWSEC.URBAN.Q3',
#  'BOTHSEX.EPRS.GRAD23.ALLAREA.Q4',
#  'NA.COPA.UPPSEC.NA.Q2',
#  'MALE.COPA._T.URBAN.NA',
#  'FEMALE.CMFL.SECOND.ALLAREA._T',
#  'BOTHSEX.PCPR.LOWSEC.RURAL.NA',
#  'BOTHSEX.LITE.PREPRI.URBAN.Q2',
#  'MALE.COPA.LOWSEC.RURAL.Q4',
#  'FEMALE.NUME.LOWSEC.ALLAREA._T',
#  'MALE.LITE.GRAD23.ALLAREA.Q1',
#  'NA.SKILL_READ.GRAD23.NA._T',
#  'MALE.NA._T.RURAL.Q2',
#  'NA.EMAIL.UPPSEC.URBAN._T',
#  'NA.CMFL.UPPSEC.URBAN._T',
#  'BOTHSEX.SKILL_READ.PRIMAR.ALLAREA._T',
#  'FEMALE.ARSP.PRIMAR.ALLAREA.NA',
#  'BOTHSEX.EMAIL.SECOND.NA._T',
#  'FEMALE.SOFT.UPPSEC.URBAN.Q3',
#  'MALE.SOFT.PREPRI.ALLAREA.Q4',
#  'FEMALE.TRAF.GRAD23.ALLAREA.Q1',
#  'NA.SKILL_MATH._T.RURAL.Q5',
#  'NA.EMAIL.PRIMAR.NA.Q3',
#  'BOTHSEX.NUME._T.URBAN.Q2',
#  'NA.SOFT.LOWSEC.URBAN.NA',
#  'FEMALE.NA.PREPRI.URBAN._T',
#  'NA.SKILL_READ.NA.URBAN.Q5',
#  'MALE.PCPR.NA.NA.Q1',
#  'NA.EPRS.PREPRI.RURAL._T',
#  'BOTHSEX.NUME.LOWSEC.RURAL.NA',
#  'FEMALE.COPA.UPPSEC.RURAL.NA',
#  'BOTHSEX.COPA.PRIMAR.ALLAREA.NA',
#  'MALE.EPRS.PREPRI.ALLAREA.Q5',
#  'MALE.TRAF.GRAD23.RURAL.Q5',
#  'MALE.EMAIL.NA.ALLAREA.Q1',
#  'BOTHSEX.TRAF.GRAD23.ALLAREA.Q2',
#  'FEMALE.PCPR.UPPSEC.URBAN.Q3',
#  'MALE.ARSP.SECOND.NA._T',
#  'MALE.SOFT.SECOND.URBAN.Q2',
#  'BOTHSEX.NA.PRIMAR.URBAN.Q3',
#  'BOTHSEX.PCPR._T.NA._T',
#  'FEMALE.PCPR.LOWSEC.ALLAREA.Q4',
#  'BOTHSEX.SKILL_MATH._T.ALLAREA.Q4',
#  'MALE.LITE.GRAD23.URBAN.Q3',
#  'MALE.CMFL.PREPRI.URBAN._T',
#  'BOTHSEX.SOFT._T.ALLAREA.Q4',
#  'MALE.INST.GRAD23.ALLAREA._T',
#  'BOTHSEX.EPRS.SECOND.URBAN.Q4',
#  'FEMALE.PCPR.UPPSEC.RURAL.NA',
#  'FEMALE.TRAF._T.NA.Q2',
#  'BOTHSEX.SKILL_READ.PRIMAR.RURAL.Q5',
#  'BOTHSEX.INST.PREPRI.URBAN.Q4',
#  'NA.LITE.PRIMAR.URBAN.Q1',
#  'MALE.PCPR.PREPRI.RURAL.Q3',
#  'BOTHSEX.SKILL_MATH.SECOND.NA.Q3',
#  'FEMALE.ARSP.UPPSEC.NA.Q2',
#  'FEMALE.SKILL_MATH._T.RURAL.Q3',
#  'NA.PCPR.PREPRI.ALLAREA.NA',
#  'MALE.COPA._T.NA.Q4',
#  'FEMALE.LITE.GRAD23.URBAN.Q2',
#  'NA.PCPR.SECOND.ALLAREA.Q2',
#  'MALE.CMFL._T.NA.Q4',
#  'MALE.INST.UPPSEC.URBAN._T',
#  'FEMALE.CMFL._T.NA.Q2',
#  'BOTHSEX.CMFL.UPPSEC.ALLAREA.Q5',
#  'MALE.ARSP.NA.NA._T',
#  'FEMALE.EMAIL.UPPSEC.ALLAREA.Q3',
#  'NA.PCPR.PRIMAR.ALLAREA._T',
#  'MALE.TRAF.UPPSEC.RURAL.NA',
#  'BOTHSEX.LITE.NA.URBAN.Q5',
#  'FEMALE.NUME.UPPSEC.ALLAREA.Q2',
#  'BOTHSEX.LITE.PREPRI.URBAN.Q1',
#  'BOTHSEX.EMAIL.LOWSEC.ALLAREA._T',
#  'BOTHSEX.NA.NA.ALLAREA.Q5',
#  'FEMALE.SKILL_READ.LOWSEC.NA._T',
#  'FEMALE.NA.LOWSEC.NA.Q5',
#  'MALE.ARSP.SECOND.ALLAREA._T',
#  'NA.INST.NA.URBAN.Q1',
#  'BOTHSEX.INST.PRIMAR.URBAN._T',
#  'BOTHSEX.EPRS.SECOND.RURAL.Q5',
#  'BOTHSEX.ARSP.UPPSEC.NA.Q1',
#  'MALE.INST._T.URBAN.Q2',
#  'NA.EPRS.PREPRI.NA.Q1',
#  'NA.TRAF.SECOND.NA.Q3',
#  'NA.SKILL_READ.UPPSEC.ALLAREA.Q5',
#  'BOTHSEX.INST._T.ALLAREA.Q4',
#  'NA.SOFT.SECOND.NA.Q2',
#  'FEMALE.SKILL_MATH.NA.NA.Q3',
#  'BOTHSEX.EMAIL.SECOND.RURAL.Q2',
#  'BOTHSEX.EPRS.PRIMAR.NA.Q5',
#  'BOTHSEX.EMAIL.SECOND.URBAN.Q5',
#  'FEMALE.PCPR.PRIMAR.NA.Q5',
#  'FEMALE.INST._T.ALLAREA.Q1',
#  'BOTHSEX.CMFL.UPPSEC.URBAN._T',
#  'MALE.TRAF.UPPSEC.ALLAREA.Q1',
#  'NA.COPA.SECOND.ALLAREA.Q4',
#  'MALE.EMAIL._T.ALLAREA.Q5',
#  'NA.COPA.UPPSEC.URBAN.Q3',
#  'BOTHSEX.ARSP._T.RURAL.Q3',
#  'MALE.SOFT.NA.ALLAREA.Q5',
#  'MALE.NA.LOWSEC.URBAN.Q1',
#  'FEMALE.ARSP.SECOND.URBAN._T',
#  'MALE.SKILL_READ.GRAD23.RURAL.Q2',
#  'NA.INST._T.URBAN.Q1',
#  'BOTHSEX.EMAIL.UPPSEC.NA.NA',
#  'BOTHSEX.COPA.PRIMAR.URBAN.Q1',
#  'NA.EPRS._T.ALLAREA.Q5',
#  'BOTHSEX.CMFL.GRAD23.RURAL._T',
#  'NA.LITE.GRAD23.RURAL.Q4',
#  'BOTHSEX.SOFT.NA.NA.Q4',
#  'BOTHSEX.TRAF.LOWSEC.RURAL.Q3',
#  'FEMALE.ARSP.NA.ALLAREA.Q4',
#  'BOTHSEX.TRAF.PREPRI.ALLAREA.Q2',
#  'NA.PCPR.PRIMAR.RURAL.Q1',
#  'FEMALE.INST.PREPRI.RURAL.Q4',
#  'NA.SOFT.GRAD23.RURAL.Q1',
#  'MALE.LITE.NA.NA.Q1',
#  'FEMALE.SKILL_MATH._T.RURAL.Q2',
#  'MALE.EMAIL.LOWSEC.URBAN.Q1',
#  'FEMALE.ARSP.UPPSEC.RURAL.NA',
#  'MALE.EPRS.GRAD23.ALLAREA.Q5',
#  'BOTHSEX.PCPR.LOWSEC.URBAN.Q4',
#  'MALE.SKILL_MATH.LOWSEC.RURAL.Q4',
#  'NA.INST.LOWSEC.RURAL.Q5',
#  'BOTHSEX.EPRS.SECOND.NA.NA',
#  'FEMALE.TRAF.PRIMAR.NA._T',
#  'NA.PCPR.LOWSEC.URBAN.NA',
#  'BOTHSEX.INST.LOWSEC.NA._T',
#  'NA.ARSP.LOWSEC.ALLAREA.NA',
#  'MALE.EPRS.GRAD23.ALLAREA.Q1',
#  'MALE.TRAF.UPPSEC.RURAL.Q5',
#  'BOTHSEX.TRAF._T.NA.Q4',
#  'MALE.COPA.NA.NA._T',
#  'BOTHSEX.SKILL_MATH.PREPRI.RURAL.Q5',
#  'FEMALE.NUME.LOWSEC.NA.Q4',
#  'NA.TRAF.PRIMAR.URBAN.NA',
#  'FEMALE.EMAIL.LOWSEC.NA.Q3',
#  'MALE.COPA.UPPSEC.RURAL.Q2',
#  'BOTHSEX.LITE.NA.URBAN.Q1',
#  'MALE.SOFT.UPPSEC.ALLAREA._T',
#  'BOTHSEX.SOFT.GRAD23.URBAN.Q1',
#  'MALE.PCPR.SECOND.URBAN._T',
#  'FEMALE.INST.SECOND.NA.NA',
#  'BOTHSEX.SKILL_READ.NA.RURAL._T',
#  'FEMALE.SOFT.GRAD23.ALLAREA.Q5',
#  'MALE.TRAF.UPPSEC.URBAN._T',
#  'FEMALE.PCPR._T.URBAN.Q2',
#  'BOTHSEX.PCPR.GRAD23.ALLAREA.NA',
#  'BOTHSEX.NUME.SECOND.NA.Q4',
#  'BOTHSEX.INST.PRIMAR.ALLAREA.Q3',
#  'MALE.NUME.LOWSEC.URBAN.Q3',
#  'MALE.EPRS.PREPRI.URBAN.Q4',
#  'NA.SKILL_MATH.SECOND.RURAL.Q3',
#  'NA.INST.PRIMAR.RURAL.NA',
#  'FEMALE.SKILL_READ.GRAD23.RURAL.Q1',
#  'NA.CMFL.GRAD23.URBAN.Q2',
#  'NA.INST.GRAD23.RURAL.Q3',
#  'BOTHSEX.NUME.SECOND.NA.Q2',
#  'FEMALE.INST.LOWSEC.ALLAREA.Q1',
#  'NA.SKILL_MATH.SECOND.RURAL.Q5',
#  'FEMALE.SOFT.UPPSEC.URBAN.Q5',
#  'MALE.LITE.GRAD23.RURAL.Q3',
#  'FEMALE.SKILL_MATH.GRAD23.RURAL.Q2',
#  'FEMALE.ARSP.SECOND.ALLAREA.NA',
#  'FEMALE.TRAF.PREPRI.NA.Q5',
#  'MALE.SOFT.GRAD23.ALLAREA.Q4',
#  'BOTHSEX.EMAIL.SECOND.NA.Q1',
#  'MALE.SKILL_READ.SECOND.ALLAREA._T',
#  'MALE.ARSP.PREPRI.RURAL.NA',
#  'NA.NUME.GRAD23.URBAN._T',
#  'MALE.SKILL_READ.NA.RURAL.Q5',
#  'NA.TRAF.LOWSEC.RURAL.NA',
#  'BOTHSEX.PCPR.LOWSEC.NA.Q5',
#  'FEMALE.COPA.NA.URBAN.NA',
#  'FEMALE.LITE._T.RURAL.Q5',
#  'MALE.ARSP.PRIMAR.ALLAREA._T',
#  'MALE.CMFL.UPPSEC.URBAN.Q4',
#  'NA.PCPR.NA.RURAL._T',
#  'MALE.COPA.UPPSEC.URBAN.Q3',
#  'FEMALE.COPA.UPPSEC.RURAL.Q1',
#  'NA.LITE.LOWSEC.ALLAREA.Q5',
#  'FEMALE.PCPR.SECOND.NA.NA',
#  'MALE.SKILL_READ.NA.NA.Q2',
#  'FEMALE.COPA.SECOND.ALLAREA.Q1',
#  'NA.SKILL_MATH.GRAD23.URBAN.Q2',
#  'NA.COPA.GRAD23.URBAN.Q4',
#  'NA.SOFT.LOWSEC.RURAL.Q5',
#  'MALE.TRAF.LOWSEC.ALLAREA.Q2',
#  'FEMALE.EMAIL._T.RURAL.Q5',
#  'BOTHSEX.NA.GRAD23.RURAL.NA',
#  'FEMALE.SKILL_READ.UPPSEC.ALLAREA.Q2',
#  'FEMALE.PCPR.NA.URBAN.Q4',
#  'BOTHSEX.NUME.NA.NA.Q5',
#  'MALE.CMFL.UPPSEC.RURAL.Q2',
#  'BOTHSEX.NUME.SECOND.RURAL.Q4',
#  'FEMALE.SKILL_MATH.LOWSEC.RURAL.Q4',
#  'NA.EPRS.NA.ALLAREA.Q4',
#  'BOTHSEX.SOFT.NA.NA.Q5',
#  'BOTHSEX.TRAF.GRAD23.NA.Q2',
#  'MALE.INST._T.ALLAREA.Q4',
#  'NA.EMAIL.PREPRI.URBAN.Q4',
#  'MALE.ARSP.PRIMAR.URBAN.Q4',
#  'FEMALE.ARSP.GRAD23.ALLAREA._T',
#  'NA.PCPR.UPPSEC.RURAL.NA',
#  'FEMALE.INST._T.URBAN.Q4',
#  'BOTHSEX.PCPR.NA.URBAN._T',
#  'BOTHSEX.NA.PRIMAR.URBAN.Q2',
#  'MALE.COPA.GRAD23.RURAL.Q2',
#  'MALE.CMFL._T.URBAN.Q3',
#  'NA.NUME.PREPRI.NA._T',
#  'NA.EMAIL.LOWSEC.NA.Q2',
#  'NA.SOFT.UPPSEC.NA.Q2',
#  'NA.NUME.UPPSEC.URBAN.Q3',
#  'BOTHSEX.SOFT.GRAD23.NA.Q4',
#  'NA.LITE._T.ALLAREA._T',
#  'BOTHSEX.SOFT.PREPRI.ALLAREA.Q4',
#  'BOTHSEX.EMAIL.NA.ALLAREA.Q3',
#  'NA.EMAIL._T.RURAL.Q1',
#  'BOTHSEX.SKILL_MATH.LOWSEC.RURAL.Q2',
#  'NA.LITE._T.URBAN.Q3',
#  'MALE.PCPR.GRAD23.ALLAREA.Q4',
#  'BOTHSEX.ARSP.NA.ALLAREA.Q2',
#  'BOTHSEX.SKILL_MATH.SECOND.RURAL.Q2',
#  'BOTHSEX.COPA._T.URBAN.Q2',
#  'FEMALE.PCPR.PRIMAR.NA._T',
#  'NA.TRAF.PRIMAR.ALLAREA.Q2',
#  'FEMALE.ARSP.GRAD23.ALLAREA.Q1',
#  'BOTHSEX.NA.LOWSEC.NA.Q3',
#  'BOTHSEX.NUME.GRAD23.NA.Q2',
#  'BOTHSEX.NUME._T.NA.Q5',
#  'NA.NA.PRIMAR.RURAL.Q3',
#  'MALE.INST.SECOND.RURAL.Q4',
#  'MALE.EPRS.LOWSEC.ALLAREA.Q1',
#  'MALE.NUME.PREPRI.RURAL.Q1',
#  'MALE.EMAIL.PREPRI.URBAN.Q5',
#  'BOTHSEX.LITE._T.URBAN.Q3',
#  'MALE.SOFT.LOWSEC.ALLAREA.Q5',
#  'BOTHSEX.EPRS.GRAD23.URBAN.Q4',
#  'NA.ARSP.NA.URBAN.NA',
#  'NA.NA.NA.NA.Q1',
#  'NA.INST.PREPRI.ALLAREA._T',
#  'FEMALE.PCPR.NA.RURAL.Q3',
#  'FEMALE.EMAIL.SECOND.RURAL.Q5',
#  'BOTHSEX.ARSP.SECOND.NA.Q3',
#  'NA.SKILL_MATH.PRIMAR.RURAL.Q4',
#  'BOTHSEX.NA.SECOND.ALLAREA.Q4',
#  'BOTHSEX.SOFT._T.RURAL._T',
#  'MALE.ARSP.NA.URBAN.NA',
#  'MALE.SKILL_READ.PREPRI.ALLAREA._T',
#  'MALE.EPRS.PRIMAR.URBAN.Q4',
#  'FEMALE.SOFT.NA.NA._T',
#  'BOTHSEX.ARSP.NA.URBAN.Q1',
#  'NA.SKILL_READ.LOWSEC.NA._T',
#  'BOTHSEX.SOFT.PREPRI.NA._T',
#  'FEMALE.EPRS.SECOND.URBAN._T',
#  'NA.ARSP._T.NA.Q5',
#  'FEMALE.TRAF.PREPRI.RURAL.Q1',
#  'NA.CMFL._T.ALLAREA.Q3',
#  'BOTHSEX.NUME.LOWSEC.ALLAREA.Q3',
#  'MALE.LITE.PREPRI.RURAL.Q4',
#  'NA.PCPR.LOWSEC.URBAN.Q1',
#  'FEMALE.NA.PREPRI.NA.Q1',
#  'BOTHSEX.CMFL.UPPSEC.RURAL.Q1',
#  'FEMALE.SKILL_READ.SECOND.ALLAREA.Q5',
#  'BOTHSEX.EMAIL.GRAD23.RURAL.Q3',
#  'BOTHSEX.EPRS.GRAD23.RURAL.Q5',
#  'FEMALE.EMAIL.UPPSEC.RURAL.Q1',
#  'BOTHSEX.TRAF.UPPSEC.NA.NA',
#  'FEMALE.LITE.UPPSEC.RURAL._T',
#  'MALE.SOFT.NA.RURAL.Q1',
#  'FEMALE.SKILL_MATH.LOWSEC.NA.Q4',
#  'FEMALE.NUME.NA.ALLAREA.Q2',
#  'FEMALE.CMFL.NA.RURAL.Q4',
#  'FEMALE.TRAF.LOWSEC.URBAN.Q2',
#  'MALE.NA.NA.NA.Q3',
#  'NA.COPA.PRIMAR.ALLAREA.NA',
#  'MALE.PCPR.GRAD23.URBAN._T',
#  'BOTHSEX.COPA.SECOND.ALLAREA.Q4',
#  'MALE.ARSP.NA.RURAL.Q4',
#  'BOTHSEX.EPRS.LOWSEC.NA.NA',
#  'NA.EMAIL.NA.NA.Q2',
#  'FEMALE.EPRS.PRIMAR.NA.Q1',
#  'NA.NA.PREPRI.URBAN.Q5',
#  'MALE.EPRS._T.NA._T',
#  'NA.CMFL.LOWSEC.RURAL.Q5',
#  'BOTHSEX.NA.SECOND.RURAL.Q3',
#  'BOTHSEX.CMFL._T.NA.NA',
#  'FEMALE.EMAIL._T.RURAL._T',
#  'FEMALE.LITE.PREPRI.URBAN.Q2',
#  'MALE.NUME._T.ALLAREA.Q3',
#  'BOTHSEX.SKILL_READ.SECOND.ALLAREA.Q1',
#  'MALE.SOFT.UPPSEC.RURAL.Q4',
#  'MALE.SOFT.PREPRI.NA.NA',
#  'NA.ARSP.LOWSEC.URBAN.Q1',
#  'NA.EMAIL.SECOND.NA.Q2',
#  'MALE.PCPR.PRIMAR.URBAN.Q3',
#  'NA.SOFT.GRAD23.NA.Q4',
#  'NA.LITE._T.RURAL.Q3',
#  'NA.NUME.LOWSEC.RURAL.Q5',
#  'BOTHSEX.EMAIL.PREPRI.URBAN._T',
#  'NA.COPA._T.NA.Q2',
#  'BOTHSEX.INST.UPPSEC.NA.Q4',
#  'FEMALE.EPRS.GRAD23.NA.Q2',
#  'NA.NUME.SECOND.RURAL.Q5',
#  'MALE.PCPR.LOWSEC.RURAL.Q3',
#  'MALE.NUME.GRAD23.URBAN._T',
#  'NA.SKILL_MATH.UPPSEC.RURAL.Q2',
#  'NA.SKILL_MATH.UPPSEC.URBAN.Q3',
#  'MALE.SOFT.NA.ALLAREA.NA',
#  'NA.SKILL_MATH._T.NA.Q4',
#  'MALE.EMAIL._T.RURAL.NA',
#  'NA.NA.NA.RURAL.NA',
#  'MALE.NA.GRAD23.RURAL.Q5',
#  'MALE.NUME._T.RURAL.Q1',
#  'NA.LITE.GRAD23.RURAL.Q5',
#  'FEMALE.TRAF.SECOND.NA._T',
#  'FEMALE.SKILL_MATH.GRAD23.URBAN.Q2',
#  'MALE.NUME.PREPRI.NA.Q5',
#  'FEMALE.CMFL.NA.NA.Q1',
#  'MALE.PCPR.PREPRI.RURAL.NA',
#  'BOTHSEX.COPA._T.RURAL.Q5',
#  'FEMALE.INST.UPPSEC.RURAL.Q3',
#  'MALE.COPA.LOWSEC.ALLAREA.Q4',
#  'BOTHSEX.CMFL.LOWSEC.ALLAREA.Q4',
#  'NA.CMFL.GRAD23.NA._T',
#  'NA.TRAF.GRAD23.RURAL._T',
#  'MALE.EPRS.NA.RURAL.NA',
#  'FEMALE.SKILL_READ.NA.URBAN.Q2',
#  'FEMALE.LITE.NA.NA._T',
#  'BOTHSEX.COPA.PRIMAR.RURAL.Q3',
#  ...]

# %%
len(feat_name_list_full)
# Out:
# 12544

# %%
# CHOOSE A SUBSET OF THIS LIST TO GET THE FEATURES WE WANT
feat_name_list = feat_name_list_full

# %%
# sex, typeOfSkill, educationLevel, location, quantile

listOfDataFrames = []
num_feat = 0
for feat in feat_name_list:
  num_feat += 1
  df_thisFeat = pd.DataFrame(columns=['GeoAreaName','Time_Detail',feat])
  featSplit = feat.split(".")
  #print(featSplit)

  sex = featSplit[0]
  typeOfSkill = featSplit[1]
  educationLevel = featSplit[2]
  location = featSplit[3]
  quantile = featSplit[4]

  num_country = 0
  for country in df['GeoAreaName'].unique():
    num_country += 1
    df_country = df[(df.GeoAreaName == country)]

    yearsForThisCountry = df_country['Time_Detail'].unique()
    #print(country,yearsForThisCountry)
    for year in yearsForThisCountry:
      #print(feat,country,year)

      df_countryYear = df_country[df_country['Time_Detail']==year]
     
      df_subset = df_countryYear[(df_countryYear['Sex']==sex) & \
                             (df_countryYear['Type of skill']==typeOfSkill) & \
                             (df_countryYear['Education level']==educationLevel) & \
                             (df_countryYear['Location']==location) & \
                             (df_countryYear['Quantile']==quantile)]
      



      val = df_subset["Value"].values
      #print(val)
      if len(val) == 1:
        #print(df_subset)
        #print(df_subset["Value"])
        d = {'GeoAreaName':country,'Time_Detail':year,feat:val[0]}
        #print(d)
        #print("******")
        df_thisFeat = df_thisFeat.append(d,ignore_index=True)
        #print(df_thisFeat.shape)

    if num_country == 1:
      break

  listOfDataFrames.append(df_thisFeat)
  #if num_feat == 10:
  #    break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-f38a6dd0bc2a> in <module>()
#      25       #print(feat,country,year)
#      26
# ---> 27       df_countryYear = df_country[df_country['Time_Detail']==year]
#      28
#      29       df_subset = df_countryYear[(df_countryYear['Sex']==sex) &                              (df_countryYear['Type of skill']==typeOfSkill) &                              (df_countryYear['Education level']==educationLevel) &                              (df_countryYear['Location']==location) &                              (df_countryYear['Quantile']==quantile)]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     370         res_values = comparison_op(lvalues, rvalues, op)
#     371
# --> 372         return self._construct_result(res_values, name=res_name)
#     373
#     374     wrapper.__name__ = op_name
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _construct_result(self, result, name)
#    2768         # We do not pass dtype to ensure that the Series constructor
#    2769         #  does inference in the case where `result` has object-dtype.
# -> 2770         out = self._constructor(result, index=self.index)
#    2771         out = out.__finalize__(self)
#    2772
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
# --> 329                 data = SingleBlockManager.from_array(data, index)
#     330
#     331         generic.NDFrame.__init__(self, data)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1576         Constructor for if we have an array that is not yet a Block.
#    1577         """
# -> 1578         block = make_block(array, placement=slice(0, len(index)), ndim=1)
#    1579         return cls(block, index)
#    1580
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2735     if klass is None:
#    2736         dtype = dtype or values.dtype
# -> 2737         klass = get_block_type(values, dtype)
#    2738
#    2739     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values.dtype):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    2699         assert not is_datetime64tz_dtype(values.dtype)
#    2700         cls = DatetimeBlock
# -> 2701     elif is_datetime64tz_dtype(values.dtype):
#    2702         cls = DatetimeTZBlock
#    2703     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/common.py in is_datetime64tz_dtype(arr_or_dtype)
#     411     True
#     412     """
# --> 413     if isinstance(arr_or_dtype, ExtensionDtype):
#     414         # GH#33400 fastpath for dtype object
#     415         return arr_or_dtype.kind == "M"
#
# KeyboardInterrupt:

# %%
listOfDataFrames
# Out:
# [Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, MALE.EPRS.GRAD23.ALLAREA.NA]
#  Index: [], Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, MALE.EPRS._T.URBAN._T]
#  Index: [], Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, BOTHSEX.NA.PREPRI.NA.Q3]
#  Index: [], Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, MALE.CMFL.GRAD23.URBAN.Q1]
#  Index: [], Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, NA.LITE.PRIMAR.NA.Q3]
#  Index: [], Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, FEMALE.INST.GRAD23.ALLAREA._T]
#  Index: [], Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, BOTHSEX.COPA.GRAD23.RURAL.Q2]
#  Index: [], Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, MALE.COPA.PRIMAR.URBAN.NA]
#  Index: [], Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, MALE.SOFT.PRIMAR.URBAN.Q4]
#  Index: [], Empty DataFrame
#  Columns: [GeoAreaName, Time_Detail, FEMALE.PCPR.LOWSEC.NA.Q2]
#  Index: []]

# %%
listOfDataFrames[0]
# Out:
#    GeoAreaName Time_Detail  BOTHSEX.SKILL_READ.GRAD23
# 0  Afghanistan        2016                  22.000000
# 1    Argentina        2006                  71.727822
# 2    Argentina        2013                  76.323888
# 3    Australia        2011                  92.932800
# 4    Australia        2016                  94.486205
# 5      Bahrain        2016                  69.368335
# 6   Bangladesh        2015                  41.000000
# 7   Bangladesh        2017                  47.000000

# %%
listOfDataFrames[1]
# Out:
#    GeoAreaName Time_Detail  BOTHSEX.SKILL_READ.LOWSEC
# 0      Albania        2000                  29.644370
# 1      Albania        2009                  43.331760
# 2      Albania        2012                  47.664562
# 3      Albania        2015                  49.722730
# 4      Albania        2018                  47.764318
# 5      Algeria        2015                  21.030629
# 6   Azerbaijan        2006                  20.584980
# 7   Azerbaijan        2009                  27.211451
# 8    Argentina        2000                  56.089186
# 9    Argentina        2006                  42.136034
# 10   Argentina        2009                  48.420489
# 11   Argentina        2012                  46.435234
# 12   Argentina        2018                  47.883647
# 13   Australia        2000                  87.538588
# 14   Australia        2003                  88.156960
# 15   Australia        2006                  86.603995
# 16   Australia        2009                  85.750376
# 17   Australia        2012                  85.807536
# 18   Australia        2015                  81.932529
# 19   Australia        2018                  80.372611
# 20     Austria        2000                  85.385365
# 21     Austria        2003                  79.296716
# 22     Austria        2006                  78.483283
# 23     Austria        2009                  72.423688
# 24     Austria        2012                  80.509781
# 25     Austria        2015                  77.460341
# 26     Austria        2018                  76.376738
# 27  Bangladesh        2013                  49.000000
# 28  Bangladesh        2015                  54.000000

# %%
listOfDataFrames[2]
# Out:
#    GeoAreaName Time_Detail  FEMALE.SKILL_MATH.GRAD23
# 0  Afghanistan        2016                 22.500000
# 1      Algeria        2007                 14.867343
# 2    Argentina        2006                 57.444123
# 3    Argentina        2013                 73.766024
# 4    Australia        2003                 63.082567
# 5    Australia        2007                 69.656837
# 6    Australia        2011                 69.124687
# 7    Australia        2015                 69.294055
# 8      Bahrain        2011                 33.431320
# 9      Bahrain        2015                 42.619916

# %%
listOfDataFrames[3]
# Out:
#    GeoAreaName Time_Detail  FEMALE.SKILL_MATH.LOWSEC
# 0      Albania        2000                 40.270000
# 1      Albania        2009                 33.670000
# 2      Albania        2012                 39.700000
# 3      Albania        2015                 48.805954
# 4      Albania        2018                 59.424983
# 5      Algeria        2015                 20.749800
# 6   Azerbaijan        2006                 89.810000
# 7   Azerbaijan        2009                 51.390000
# 8    Argentina        2000                 42.520000
# 9    Argentina        2006                 34.000000
# 10   Argentina        2009                 34.400000
# 11   Argentina        2012                 30.280000
# 12   Argentina        2018                 27.213665
# 13   Australia        2000                 88.850000
# 14   Australia        2003                 86.240000
# 15   Australia        2006                 86.390000
# 16   Australia        2009                 83.690000
# 17   Australia        2012                 78.850000
# 18   Australia        2015                 78.123101
# 19   Australia        2018                 77.342295
# 20     Austria        2000                 82.610000
# 21     Austria        2003                 81.630000
# 22     Austria        2006                 77.270000
# 23     Austria        2009                 74.940000
# 24     Austria        2012                 78.810000
# 25     Austria        2015                 75.232747
# 26     Austria        2018                 78.336506
# 27     Bahrain        2003                 20.825517
# 28     Bahrain        2007                 21.055600
# 29     Bahrain        2011                 30.510134
# 30     Bahrain        2015                 43.184065
# 31  Bangladesh        2013                 29.000000
# 32  Bangladesh        2015                 52.000000
# 33     Armenia        2003                 56.269845
# 34     Armenia        2007                 63.811022
# 35     Armenia        2011                 51.413915
# 36     Armenia        2015                 51.801026

# %%
listOfDataFrames[4]
# Out:
#    GeoAreaName Time_Detail  MALE.SKILL_MATH.GRAD23
# 0  Afghanistan        2016               26.500000
# 1      Algeria        2007               13.209358
# 2    Argentina        2006               56.624427
# 3    Argentina        2013               68.402758
# 4    Australia        2003               64.380439
# 5    Australia        2007               71.636174
# 6    Australia        2011               71.207350
# 7    Australia        2015               71.120873
# 8      Bahrain        2011               34.241277
# 9      Bahrain        2015               37.270044

# %%
listOfDataFrames[5]
# Out:
#     GeoAreaName Time_Detail  BOTHSEX.SKILL_MATH.PRIMAR
# 0   Afghanistan        2013                  11.000000
# 1    Azerbaijan        2011                  46.419939
# 2     Argentina        2006                  48.594414
# 3     Argentina        2013                  55.602812
# 4     Australia        2003                  64.863053
# 5     Australia        2007                  60.785010
# 6     Australia        2011                  62.941286
# 7     Australia        2015                  64.432914
# 8       Austria        2007                  68.897266
# 9       Austria        2011                  70.434049
# 10   Bangladesh        2015                  25.000000
# 11   Bangladesh        2017                  32.000000
# 12      Armenia        2003                  42.745863
# 13      Armenia        2007                  59.995814
# 14      Armenia        2011                  40.919326
# 15      Armenia        2015                  54.563823

# %%
len(listOfDataFrames)
# Out:
# 18

# %%
listOfDataFrames_copy = listOfDataFrames

# %%
df_new = pd.merge(listOfDataFrames[0], listOfDataFrames[1],  how='left', left_on=['GeoAreaName','Time_Detail'], right_on = ['GeoAreaName','Time_Detail'])
for i in range(2,18):
  df_new = pd.merge(df_new, listOfDataFrames[i],  how='left', left_on=['GeoAreaName','Time_Detail'], right_on = ['GeoAreaName','Time_Detail'])

# %%
df_new
# Out:
#                   GeoAreaName  ... FEMALE.SKILL_MATH.PRIMAR
# 0                 Afghanistan  ...                      NaN
# 1                   Argentina  ...                47.933275
# 2                   Argentina  ...                52.527277
# 3                   Australia  ...                61.604058
# 4                   Australia  ...                      NaN
# ..                        ...  ...                      ...
# 169  United States of America  ...                      NaN
# 170  United States of America  ...                      NaN
# 171              Burkina Faso  ...                17.900000
# 172                   Uruguay  ...                73.388436
# 173                   Uruguay  ...                67.054896
#
# [174 rows x 20 columns]

# %%
df_new.columns
# Out:
# Index(['GeoAreaName', 'Time_Detail', 'BOTHSEX.SKILL_READ.GRAD23',
#        'BOTHSEX.SKILL_READ.LOWSEC', 'FEMALE.SKILL_MATH.GRAD23',
#        'FEMALE.SKILL_MATH.LOWSEC', 'MALE.SKILL_MATH.GRAD23',
#        'BOTHSEX.SKILL_MATH.PRIMAR', 'MALE.SKILL_READ.GRAD23',
#        'MALE.SKILL_MATH.LOWSEC', 'FEMALE.SKILL_READ.LOWSEC',
#        'BOTHSEX.SKILL_READ.PRIMAR', 'FEMALE.SKILL_READ.GRAD23',
#        'BOTHSEX.SKILL_MATH.LOWSEC', 'MALE.SKILL_READ.PRIMAR',
#        'FEMALE.SKILL_READ.PRIMAR', 'BOTHSEX.SKILL_MATH.GRAD23',
#        'MALE.SKILL_MATH.PRIMAR', 'MALE.SKILL_READ.LOWSEC',
#        'FEMALE.SKILL_MATH.PRIMAR'],
#       dtype='object')

# %%
df_origCols = df_new[['GeoAreaName','Time_Detail']]

df_dataOnly = df_new[['BOTHSEX.SKILL_READ.GRAD23',
       'BOTHSEX.SKILL_READ.LOWSEC', 'FEMALE.SKILL_MATH.GRAD23',
       'FEMALE.SKILL_MATH.LOWSEC', 'MALE.SKILL_MATH.GRAD23',
       'BOTHSEX.SKILL_MATH.PRIMAR', 'MALE.SKILL_READ.GRAD23',
       'MALE.SKILL_MATH.LOWSEC', 'FEMALE.SKILL_READ.LOWSEC',
       'BOTHSEX.SKILL_READ.PRIMAR', 'FEMALE.SKILL_READ.GRAD23',
       'BOTHSEX.SKILL_MATH.LOWSEC', 'MALE.SKILL_READ.PRIMAR',
       'FEMALE.SKILL_READ.PRIMAR', 'BOTHSEX.SKILL_MATH.GRAD23',
       'MALE.SKILL_MATH.PRIMAR', 'MALE.SKILL_READ.LOWSEC',
       'FEMALE.SKILL_MATH.PRIMAR']]

# %%
df_origCols
# Out:
#                   GeoAreaName Time_Detail
# 0                 Afghanistan        2016
# 1                   Argentina        2006
# 2                   Argentina        2013
# 3                   Australia        2011
# 4                   Australia        2016
# ..                        ...         ...
# 169  United States of America        2011
# 170  United States of America        2016
# 171              Burkina Faso        2014
# 172                   Uruguay        2006
# 173                   Uruguay        2013
#
# [174 rows x 2 columns]

# %%
df_dataOnly
# Out:
#      BOTHSEX.SKILL_READ.GRAD23  ...  FEMALE.SKILL_MATH.PRIMAR
# 0                    22.000000  ...                       NaN
# 1                    71.727822  ...                 47.933275
# 2                    76.323888  ...                 52.527277
# 3                    92.932800  ...                 61.604058
# 4                    94.486205  ...                       NaN
# ..                         ...  ...                       ...
# 169                  97.517359  ...                       NaN
# 170                  96.094080  ...                       NaN
# 171                  35.590000  ...                 17.900000
# 172                  75.350014  ...                 73.388436
# 173                  79.785388  ...                 67.054896
#
# [174 rows x 18 columns]

# %%
dataColNames = df_dataOnly.columns
X = df_dataOnly.to_numpy()

# %%
X
# Out:
# array([[22.        ,         nan, 22.5       , ...,         nan,
#                 nan,         nan],
#        [71.72782174, 42.13603413, 57.44412343, ..., 50.83023243,
#         33.1       , 47.93327546],
#        [76.32388756,         nan, 73.76602371, ..., 58.62759568,
#                 nan, 52.52727731],
#        ...,
#        [35.59      ,         nan, 56.79      , ..., 24.12      ,
#                 nan, 17.9       ],
#        [75.35001415, 53.36259043, 69.05911158, ..., 73.88288705,
#         45.26      , 73.38843629],
#        [79.78538797,         nan, 76.90927529, ..., 69.4939529 ,
#                 nan, 67.05489614]])

# %%
dataColNames
# Out:
# Index(['BOTHSEX.SKILL_READ.GRAD23', 'BOTHSEX.SKILL_READ.LOWSEC',
#        'FEMALE.SKILL_MATH.GRAD23', 'FEMALE.SKILL_MATH.LOWSEC',
#        'MALE.SKILL_MATH.GRAD23', 'BOTHSEX.SKILL_MATH.PRIMAR',
#        'MALE.SKILL_READ.GRAD23', 'MALE.SKILL_MATH.LOWSEC',
#        'FEMALE.SKILL_READ.LOWSEC', 'BOTHSEX.SKILL_READ.PRIMAR',
#        'FEMALE.SKILL_READ.GRAD23', 'BOTHSEX.SKILL_MATH.LOWSEC',
#        'MALE.SKILL_READ.PRIMAR', 'FEMALE.SKILL_READ.PRIMAR',
#        'BOTHSEX.SKILL_MATH.GRAD23', 'MALE.SKILL_MATH.PRIMAR',
#        'MALE.SKILL_READ.LOWSEC', 'FEMALE.SKILL_MATH.PRIMAR'],
#       dtype='object')

# %%
# knn imputation

import numpy as np
from sklearn.impute import KNNImputer
nan = np.nan
X = df_dataOnly.to_numpy()
imputer = KNNImputer(n_neighbors=2, weights="uniform") # not too high since data is sparse
df_imputeDataOnly = imputer.fit_transform(X)

# %%
df_imputeDataOnly = pd.DataFrame(data=df_imputeDataOnly,columns=dataColNames)

# %%
df_imputeDataOnly
# Out:
#      BOTHSEX.SKILL_READ.GRAD23  ...  FEMALE.SKILL_MATH.PRIMAR
# 0                    22.000000  ...                 14.478434
# 1                    71.727822  ...                 47.933275
# 2                    76.323888  ...                 52.527277
# 3                    92.932800  ...                 61.604058
# 4                    94.486205  ...                 68.819378
# ..                         ...  ...                       ...
# 169                  97.517359  ...                 70.300225
# 170                  96.094080  ...                 68.819378
# 171                  35.590000  ...                 17.900000
# 172                  75.350014  ...                 73.388436
# 173                  79.785388  ...                 67.054896
#
# [174 rows x 18 columns]

# %%
df_imputed = pd.concat([df_origCols, df_imputeDataOnly], axis=1)

# %%
df_imputed
# Out:
#                   GeoAreaName  ... FEMALE.SKILL_MATH.PRIMAR
# 0                 Afghanistan  ...                14.478434
# 1                   Argentina  ...                47.933275
# 2                   Argentina  ...                52.527277
# 3                   Australia  ...                61.604058
# 4                   Australia  ...                68.819378
# ..                        ...  ...                      ...
# 169  United States of America  ...                70.300225
# 170  United States of America  ...                68.819378
# 171              Burkina Faso  ...                17.900000
# 172                   Uruguay  ...                73.388436
# 173                   Uruguay  ...                67.054896
#
# [174 rows x 20 columns]

# %%
df_imputed

# %%
df_imputed.to_csv(data_path+"df_imputed_MoreFeatures.csv")
